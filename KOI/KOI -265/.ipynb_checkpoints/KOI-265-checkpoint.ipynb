# %% [markdown]
# # Importing Module

# %%
#kplr used to import koi data easier
import kplr
client = kplr.API()

#used to open .fits files
import pyfits
# import astropy

#Used for Plotting
#Experimenting with this instead of using matplot.lib
from bokeh.plotting import figure, show, output_file,output_notebook
#Allows for viewing of plots on jupyter notebooks
output_notebook()

#For Maximum Likelihood
from scipy import optimize

#Used for scientific computing
import numpy as np

#For making copies of data
import copy

#Needed to correct median with 'nan' data points
import math

#For Periodogram
from gatspy.periodic import LombScargleFast

#Importing and notebook setup
# %matplotlib inline

#For Plotting
import matplotlib.pyplot as plt

#adjusting data using pyke
import pyke

#for astro constants
from astropy.constants import *

#needed for bls function
import math
#median
import statistics
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cdbdf2d7-4fc6-44f7-8f01-d1e260efab05">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Making useful functions

# %% [markdown]
# Removing "nan" Flux Data Points

# %%
#Removes nan data points
def remove_nan(datax,datay):
    #array of nan points location in flux array
    nan_points=np.array([])
    
    #finds points that have nan as data point
    for j in range(0,len(datax)-1):
        if math.isnan(datay[j])==True:
            nan_points = np.append(nan_points,j)
            
    #deletes the points with nan and correspoding time
    datax = np.delete(datax,nan_points)
    datay = np.delete(datay,nan_points)
        
    return(datax,datay)

# %% [markdown]
# Removing Outliers

# %%
#datax - time data
#datay - flux data
#cutoff - flux larger than this value get removed
def remove_outlier(datax, datay, cutoff):
    outlier_points = np.array([])
    
    for i in range(0,len(datay)-1):
        if f[i]>cutoff:
            outlier_points = np.append(outlier_points,i)

    print outlier_points
    #deletes the points with nan and correspoding time
    datax = np.delete(datax,outlier_points)
    datay = np.delete(datay,outlier_points)
    
    return (datax, datay)

# %% [markdown]
# Lists all Outliers

# %%
#datay - flux
#maxdelta - max change from points to not be considered an outlier
def list_outliers(datay, maxdelta):
    
    outlier_points = np.array([])
    for i in range(1,len(datay)):
        delta = datay[i] - datay[i-1]
        
        if delta > maxdelta:
            a = int(i)
            outlier_points = np.append(outlier_points,a)
    
    return outlier_points

# %% [markdown]
# Median Smooth

# %%
def median_smooth(time,flux,interval):    
    x = 0
    f_q = copy.copy(flux)
    #remomving nan values
    t_q,f_q= remove_nan(time,f_q)
    f_sort=f_q[0:interval]
    
    while x+2< len(f_q)-3:
        f_sort = np.sort(f_q[x:x+interval]) #sort data min to max
        f_median = statistics.median(f_sort) #find median
        f_q[2+x] = f_median #replace value with median
        x = x+1
    
    return (t_q,f_q)

# %% [markdown]
# Periodograms

# %%
######Lomb-Scargle Periodogram##########

# Used to find periodic activity of star 
### Works only if you remove "nan" data points
#1st argument: time data
#2nd argument: flux data
#3rd argument: range minimum for finding period
#4th argument: range maximum for finding period
#5th argument: time between data points
def periodogram(datax, datay, min_per, max_per, nyquist):
    #finding periodogram
    model = LombScargleFast().fit(datax, datay)
    period, power = model.periodogram_auto(nyquist_factor=nyquist)

    #Plotting
    periodogram = figure(
        x_axis_label="Period",
        x_axis_type="log",
        y_axis_label="Power",
        title = 'Lomb-Scargle Periodogram',
        tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

    #adding x and y data for plot
    periodogram.line(period,power)

    #showing results
    show(periodogram)

    # set range and find period
    model.optimizer.period_range=(min_per, max_per)
    period = model.best_period
    print("period = {0}".format(period))
    return period

# %% [markdown]
# BLS Function

# %%
#### Copying code from: https://ridlow.wordpress.com/category/ipython-notebook/

# t - time is an N-dimensional array of timestamps for the light curve,
# x - flux is the N-dimensional light curve array,
# qmi is the minimum transit duration to test, and
# qma is the maximum transit duration to test.
# fmin is the minimum frequency to test,
# df is the frequency grid spacing,
# nb is the number of bins to use in the folded light curve,
# nf is the number of frequency bins to test,

def bls(t, x, qmi, qma, fmin, df, nf, nb):
    """Frist trial, BLS algorithm, only minor modification from author's code"""
    
    n = len(t); rn = len(x)
    #! use try
    if n != rn:
        print "Different size of array, t and x"
        return 0

    rn = float(rn) # float of n

    minbin = 5
    nbmax = 2000
    if nb > nbmax:
        print "Error: NB > NBMAX!"
        return 0

    tot = t[-1] - t[0] # total time span

    if fmin < 1.0/tot:
        print "Error: fmin < 1/T"
        return 0

    # parameters in binning (after folding)
    kmi = int(qmi*nb) # nb is number of bin -> a single period
    if kmi < 1: 
        kmi = 1
    kma = int(qma*nb) + 1
    kkmi = rn*qmi # to check the bin size
    if kkmi < minbin: 
        kkmi = minbin

    # For the extension of arrays (edge effect: transit happen at the edge of data set)
    nb1 = nb + 1
    nbkma = nb + kma
        
    # Data centering
    t1 = t[0]
    u = t - t1
    s = np.mean(x) # ! Modified
    v = x - s

    bpow = 0.0
    p = np.zeros(nf)
    # Start period search
    for jf in range(nf):
        f0 = fmin + df*jf # iteration in frequency not period
        p0 = 1.0/f0

        # Compute folded time series with p0 period
        ibi = np.zeros(nbkma)
        y = np.zeros(nbkma)
        for i in range(n):
            ph = u[i]*f0 # instead of t mod P, he use t*f then calculate the phase (less computation)
            ph = ph - int(ph)
            j = int(nb*ph) # data to a bin 
            ibi[j] = ibi[j] + 1 # number of data in a bin
            y[j] = y[j] + v[i] # sum of light in a bin
        
        # Extend the arrays  ibi()  and  y() beyond nb by wrapping
        for j in range(nb1, nbkma):
            jnb = j - nb
            ibi[j] = ibi[jnb]
            y[j] = y[jnb]

        # Compute BLS statictics for this trial period
        power = 0.0

        for i in range(nb): # shift the test period
            s = 0.0
            k = 0
            kk = 0
            nb2 = i + kma
            # change the size of test period (from kmi to kma)
            for j in range(i, nb2): 
                k = k + 1
                kk = kk + ibi[j]
                s = s + y[j]
                if k < kmi: continue # only calculate SR for test period > kmi
                if kk < kkmi: continue # 
                rn1 = float(kk)
                powo = s*s/(rn1*(rn - rn1))
                if powo > power: # save maximum SR in a test period
                    power = powo # SR value
                    jn1 = i # 
                    jn2 = j
                    rn3 = rn1
                    s3 = s

        power = math.sqrt(power)
        p[jf] = power

        if power > bpow:
            bpow = power # Save the absolute maximum of SR
            in1 = jn1
            in2 = jn2
            qtran = rn3/rn
            # depth = -s3*rn/(rn3*(rn - rn3))
            # ! Modified
            high = -s3/(rn - rn3)
            low = s3/rn3
            depth = high - low
            bper = p0
    
    # ! add
    sde = (bpow - np.mean(p))/np.std(p) # signal detection efficiency

    return bpow, in1, in2, qtran, depth, bper, sde, p, high, low

# %% [markdown]
# # Beginning to Look at Data

# %% [markdown]
# Importing Data

# %%
# Find a KOI.
koi = client.koi(265.01)

#period, period error (postive & negative)
# print 'Period w/ errors: ',(koi.koi_period, koi.koi_period_err1, koi.koi_period_err2)

# This KOI has an associated star.
# star = koi.star
# print star
# print "Associated Star Temperature: ",(star.kic_teff)

#Download the lightcurves for this KOI.
lightcurves = koi.get_light_curves(short_cadence=False)
# for lc in lightcurves:
#     print (lc.filename)
print "Kepler ID ", koi.kepid
# Out:
# Kepler ID  12024120

# %% [markdown]
# Getting Like Curve Data

# %%
# Loop over the datasets and read in the data.
#Open the FITS data file and return the ``pyfits.HDUList``. This will
#download the file if it isn't already saved locally.
datacol = "PDCSAP_FLUX"
errcol = "PDCSAP_FLUX_ERR"
time, flux, ferr, quality = [], [], [], []
for lc in lightcurves:
    with lc.open() as f:
        # The lightcurve data are in the first FITS HDU.
        #can also append "SAP_Flux
        hdu_data = f[1].data
        time.append(hdu_data["time"])
        flux.append(hdu_data[datacol])
        ferr.append(hdu_data[errcol])
        quality.append(hdu_data["sap_quality"])

# %% [markdown]
# Initial Plot of Data

# %%
# Time (BJD - 2454833)
#Flux (e-/sec) + ____e+4
q_l = 9
q_h = 12
quarters = np.linspace(q_l,q_h,q_h+1-q_l,dtype=int)
BJD = 245833
#Following Labels are used for all graphs
x_label = 'Time + (BJD - %d)' %BJD
y_label = 'Flux(e-/sec)'
title = 'Kepler ID: %d'%(koi.kepid)


#Creating new plot with title and axis labels
#Plot is an object
lc_plot_265 = figure(
    title=title, 
    x_axis_label=x_label,
    y_axis_label=y_label,
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot

color = ('blue', 'red', 'green', 'orange')
print 'Quarters:', q_l, ' - ',q_h
for x in range(q_l,q_h+1):
    legend = 'Quarter %d' % x
    if x % 2 == 1:
        lc_plot_265.circle(time[x], flux[x],color='red')
    if x % 2 == 0:
        lc_plot_265.circle(time[x], flux[x],color='blue')

#showing results
show(lc_plot_265)
# Out:
# Quarters: 9  -  12
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="321c5482-768b-4575-8aa9-cdce8ea25722"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("321c5482-768b-4575-8aa9-cdce8ea25722");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("321c5482-768b-4575-8aa9-cdce8ea25722");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '321c5482-768b-4575-8aa9-cdce8ea25722' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"abb8f201-e825-44d3-8e86-f57362668e27":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1001.2084630813624,1001.228896255634,1001.249329629667,1001.2697629032409,1001.2901962768083,1001.3106294501486,1001.3310627232568,1001.3514960961256,1001.3719292690002,1001.39236254141,1001.4127959135803,1001.4332291855244,1001.4536623572349,1001.4740957287067,1001.4945290001851,1001.5149621711971,1001.5353955419705,1001.5558287125168,1001.5762620830646,1001.5966953531388,1001.6171285232194,1001.637561892836,1001.
# %% [markdown]
# ## Method 1: Detrending Method, Running Average

# %% [markdown]
# Step 1: cleaning data, median smoothing to remove outliers

# %%
interval = 7
f_median_smooth = []
t_median_smooth = []

for i in range(q_l,q_h+1):
    t_q,f_q = median_smooth(time[i],flux[i],interval)   
        
    #adding all values for quarter i
    f_median_smooth.append(f_q)
    t_median_smooth.append(t_q)

# %%
#Plot is an object
lc_median_smooth_265 = figure(
    title= title, 
    x_axis_label= x_label,
    y_axis_label=y_label,
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
print 'Quarters:', q_l, ' - ',q_h
for x in range(0,len(quarters)):
    q_plt = quarters[x]
    legend = 'Quarter %d' % q_plt
    if x%2 ==0:
        lc_median_smooth_265.circle(time[q_plt],flux[q_plt],fill_alpha = .2,line_alpha=.2)
        lc_median_smooth_265.circle(t_median_smooth[x], f_median_smooth[x],color='purple')
    if x%2 ==1:
        lc_median_smooth_265.circle(time[q_plt],flux[q_plt],fill_alpha = .2,line_alpha=.2)
        lc_median_smooth_265.circle(t_median_smooth[x], f_median_smooth[x],color='green')

show(lc_median_smooth_265)
# Out:
# Quarters: 9  -  12
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3af11841-a5ad-4fa5-afdc-74c66585b51f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3af11841-a5ad-4fa5-afdc-74c66585b51f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3af11841-a5ad-4fa5-afdc-74c66585b51f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3af11841-a5ad-4fa5-afdc-74c66585b51f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9a15ee6c-fa2f-4ce7-aed2-6969b800eb71":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7ef41ad5-1555-4799-ab23-0b066474c7a0","type":"Circle"},{"attributes":{"callback":null},"id":"aa01b511-5359-48ca-8ad8-5e557444370e","type":"DataRange1d"},{"attributes":{"callback":null,"overlay":{"id":"dc11c1f7-bb1e-465b-9d6e-fb9c5dd877c0","type":"BoxAnnotation"},"plot":{"id":"57ee7588-a033-4162-a520-946d04706372","subtype":"Figure","type":"Plot"},"renderers":[{"id":"b35e816d-3805-4351-88f6-138b422f1c90","type":"GlyphRenderer"},{"id":"cf2b43e6-f1c0-422c-b52a-e871906c4ff9","type":"GlyphRenderer"},{"id":"0f9f87d3-5c97-4bcb-9e83-97f1ae9433c3","type":"GlyphRenderer"},{"id":"65f62e2b-0413-4eb0-98e3-bf0d2a84d93c","type":"GlyphRenderer"},{"id":"bf593ca9-9047-4b28-8567-ab06914b4448","type":"GlyphRenderer"},{"id":"54379b2d-8951-4529-8189-4f51f8d02eaf","type":"GlyphRenderer"},{"id":"a057e746-7bcb-4fe3-b487-18f31d8b4d07","type":"GlyphRenderer"},{"id":"56b11dac-ed02-4507-b7cf-d1ef4308d38f","type":"GlyphRenderer"}]},"id":"3fa3bbf0-5ae7-4fc1-a05b-fa1de39495af","type":"BoxSelectTool"},{"attributes":{"callback":null,"plot":{"id":"57ee7588-a033-4162-a520-946d04706372","subtype":"Figure","type":"Plot"}},"id":"da997165-ecfc-4af5-a7f6-21c6ac776298","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

print 'Quarters:', q_l, ' - ',q_h
#adding x and y data for plot
for x in range(0,len(quarters)):
    q_plt = quarters[x]
#     legend = 'Normalized Flux Q%d'% q_plt
    if x%2 ==0:
        lc_normal_265.circle(t_median_smooth[x], f_normalized[x],color='purple')
    if x%2 ==1:
#         lc_normal_265.circle(t_no_outlier[x], f_normalized[x],legend='Cleaned Flux Quater %d' %q_plt,color='green')
        lc_normal_265.circle(t_median_smooth[x], f_normalized[x],color='green')

show(lc_normal_265)
# Out:
# Quarters: 9  -  12
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="38ebc00e-bbfe-4296-93bb-9873f4e1f46a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("38ebc00e-bbfe-4296-93bb-9873f4e1f46a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("38ebc00e-bbfe-4296-93bb-9873f4e1f46a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '38ebc00e-bbfe-4296-93bb-9873f4e1f46a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d5e566d1-ced6-4fc6-bf01-6747f94f3d80":{"roots":{"references":[{"attributes":{"overlay":{"id":"72425019-5f5d-41cd-912e-88989add83c2","type":"BoxAnnotation"},"plot":{"id":"f0f19d6a-a67f-48a7-a7ef-1161d9ccf18f","subtype":"Figure","type":"Plot"}},"id":"3cecc5b0-df16-4607-842e-0e3450261e9c","type":"BoxZoomTool"},{"attributes":{},"id":"27b268af-b787-4e37-b496-c2745650cc2a","type":"BasicTickFormatter"},{"attributes":{},"id":"1be24a20-bc79-413f-bc69-79a35831c666","type":"LinearScale"},{"attributes":{},"id":"5a98fe62-ba10-48ce-994b-6b0eb7838399","type":"ToolEvents"},{"attributes":{},"id":"cffb6a38-8b58-4575-af87-0b6f0ffa74ee","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2138b098-7f5c-4896-9f01-333ef208d38a","type":"Circle"},{"attributes":{"below":[{"id":"ba26474d-0500-42a9-8556-eb4bbf562e1b","type":"LinearAxis"}],"left":[{"id":"ca8a6f0a-1990-4052-9d35-ed14c4ef5c36","type":"LinearAxis"}],"renderers":[{"id":"ba26474d-0500-42a9-8556-eb4bbf562e1b","type":"LinearAxis"},{"id":"2a3c9b28-9c56-4fc9-ae09-59910b4d89a4","type":"Grid"},{"id":"ca8a6f0a-1990-4052-9d35-ed14c4ef5c36","type":"LinearAxis"},{"id":"9db8207f-a9ce-4e4b-94cc-49db91524861","type":"Grid"},{"id":"72425019-5f5d-41cd-912e-88989add83c2","type":"BoxAnnotation"},{"id":"53ffabe7-ca29-4ab3-a76e-e4ea6d841ba7","type":"BoxAnnotation"},{"id":"512c3a6b-1edf-4df5-920e-757f8eb494c9","type":"GlyphRenderer"},{"id":"75381da5-7dfd-411c-aa9c-35b3aa6b2a20","type":"GlyphRenderer"},{"id":"45b9277d-8eb7-423f-92e7-773784e1cc46","type":"GlyphRenderer"},{"id":"4f0dcc10-baee-467d-a46e-e515ee29c835","type":"GlyphRenderer"}],"title":{"id":"77ecd173-f2cb-45aa-b8b2-b2b089234ec6","type":"Title"},"tool_events":{"id":"5a98fe62-ba10-48ce-994b-6b0eb7838399","type":"ToolEvents"},"toolbar":{"id":"f6b7900f-710e-483e-a02a-f8b5f7df046b","type":"Toolbar"},"x_range":{"id":"f4a83b6b-6959-441b-aa54-46a6dd78f067","type":"DataRange1d"},"x_scale":{"id":"1be24a20-bc79-413f-bc69-79a35831c666","type":"LinearScale"},"y_range":{"id":"b2f172a4-b53d-4159-9ff5-7b0ae46af72f","type":"DataRange1d"},"y_scale":{"id":"5927c763-68f8-4318-a074-68b0b297baf3","type":"LinearScale"}},"id":"f0f19d6a-a67f-48a7-a7ef-1161d9ccf18f","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"f0f19d6a-a67f-48a7-a7ef-1161d9ccf18f","subtype":"Figure","type":"Plot"},"ticker":{"id":"c0e688ac-b79f-4a96-902c-fb14d02d6bac","type":"BasicTicker"}},"id":"9db8207f-a9ce-4e4b-94cc-49db91524861","type":"Grid"},{"attributes":{"data_source":{"id":"70bd8e93-f153-4413-9485-05bf3128eb6a","type":"ColumnDataSource"},"glyph":{"id":"2e8f4045-aa09-4613-a9f0-91badae9aac7","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d1413a87-7189-477a-8ae5-aa5883bf1b75","type":"Circle"},"selection_glyph":null},"id":"512c3a6b-1edf-4df5-920e-757f8eb494c9","type":"GlyphRenderer"},{"attributes":{"callback":null,"plot":{"id":"f0f19d6a-a67f-48a7-a7ef-1161d9ccf18f","subtype":"Figure","type":"Plot"}},"id":"1b0fff5d-7854-439b-8f74-0675aafa1b83","type":"TapTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"53ffabe7-ca29-4ab3-a76e-e4ea6d841ba7","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"7110d1ae-5591-4d68-96ff-63d07087b8a0","type":"ColumnDataSource"},"glyph":{"id":"035440c6-9250-41b3-baea-b2a3c296b8ee","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"820d0abb-229d-46c7-9007-806aa365b41c","type":"Circle"},"selection_glyph":null},"id":"75381da5-7dfd-411c-aa9c-35b3aa6b2a20","type":"GlyphRenderer"},{"attributes":{},"id":"92c26305-70f2-4b0f-a20a-b1 ...

# %% [markdown]
# Step 3: Running Average or Median

# %%
f_normalized = np.hstack(f_normalized)
t_no_outlier = np.hstack(t_median_smooth)
npts = int(len(f_normalized))
print np.sqrt(npts)
# Out:
# 130.663690442

# %%
n = 91 #odd number around value of sqrt above
c = copy.copy(f_normalized)


for i in range(0,len(f_normalized)-(n)+1):
    low_r = i
    high_r = low_r + n
    center = i + (n+1)/2
    data = f_normalized[low_r:high_r]
    running = np.mean(data,dtype=np.float64) #running average
#     running = np.float64( "%f" % np.median(data))
    c[center] = running

# %%
low_r = (n+1)/2
# high_r = len(f_no_outlier)-low_r
# f_detrend = (f_no_outlier[low_r:high_r]/ c[low_r:high_r])
low_r = (n+1)/2
high_r = len(f_normalized)-low_r
f_detrend = (f_normalized[low_r:high_r]/ c[low_r:high_r])
t_detrend = t_no_outlier[low_r:high_r]

# %%
#Plot is an object
lc_detrend_265 = figure(
    title= title, 
    x_axis_label= x_label,
    y_axis_label=normalized_label,
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
lc_detrend_265.circle(t_no_outlier,f_normalized,legend='Normalized Flux',fill_alpha = .1,line_alpha=.1, color = 'green')
lc_detrend_265.circle(t_detrend,f_detrend ,legend='Detrend Flux',color='red')
show(lc_detrend_265)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id
ool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f6174c4a-f50c-4fc5-bcf6-584da1e1b022","type":"HoverTool"},{"id":"5f348eda-afbb-4192-8526-e55559c30980","type":"CrosshairTool"},{"id":"4390f975-c306-4179-b511-c1b64297daaa","type":"PanTool"},{"id":"c77e989d-7285-4ec7-84c2-389066dd5a83","type":"WheelZoomTool"},{"id":"9a942183-0e5b-437c-b31c-5bc50bdfa92c","type":"BoxZoomTool"},{"id":"ba4a1fcf-a0d7-43c1-b013-9f9a28a45f30","type":"ResetTool"},{"id":"771cd580-2c43-41f8-8194-d5e355f53c32","type":"TapTool"},{"id":"309ffc89-5443-4456-ab29-0987c4a779be","type":"SaveTool"},{"id":"d5ea4fa6-e774-423d-9a44-9890638f65b4","type":"BoxSelectTool"}]},"id":"c83f7056-0343-45b7-99fb-272a92f871db","type":"Toolbar"},{"attributes":{"plot":{"id":"5e4c4908-3c5b-417a-ab9b-22fd7fe0805d","subtype":"Figure","type":"Plot"},"ticker":{"id":"70c3e41b-251a-4817-970a-1b28bdf0b5f8","type":"BasicTicker"}},"id":"5ab29f83-16c9-420d-8491-200995f52b45","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_al ...

# %% [markdown]
# Step 4: Periodogram and BLS

# %%
#1st argument: time data
#2nd argument: flux data
#3rd argument: minimum period
#4th argument: max period
#5th argument: time between data points
min_period = .1
max_period = (max(t_median_smooth[0])-min(t_median_smooth[0]))/3.
# max_period = 4
nyquist = .02 #30min flux samples
period1 = periodogram(t_detrend,f_detrend,min_period,max_period,nyquist)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="85a4ea8d-459e-4423-9ef3-d82c79e3fe18"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("85a4ea8d-459e-4423-9ef3-d82c79e3fe18");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("85a4ea8d-459e-4423-9ef3-d82c79e3fe18");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '85a4ea8d-459e-4423-9ef3-d82c79e3fe18' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0b9cd1e9-22c9-4f42-acbd-711e4b4a4017":{"roots":{"references":[{"attributes":{"plot":{"id":"f8dba34a-3427-43cc-912e-3f9adbc56919","subtype":"Figure","type":"Plot"}},"id":"dd74be61-8021-4939-9060-62ab091aef96","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[849]},"y":{"__ndarray__":"...","dtype":"float64","shape":[849]}}},"id":"e97812f5-ac0b-46dc-9ae7-4b2465ce1ea1","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"f8dba34a-3427-43cc-912e-3f9adbc56919","subtype":"Figure","type":"Plot"},"ticker":{"id":"a4e699fe-dc0e-42f5-89fc-3bd909cb23f0","type":"BasicTicker"}},"id":"a77690d2-f9de-428c-89e4-7a441715f238","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d68646b2-775a-490e-a247-de90a1975323","type":"BoxAnnotation"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"60c560b2-4eed-4de3-9dd9-f4bb7628782e","type":"BoxAnnotation"},{"attributes":{"ticker":null},"id":"a6678f27-c0db-4fb2-9243-c831889c270b","type":"LogTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4426912d-18fb-4d69-ae45-1b095fe7a42e","type":"Line"},{"attributes":{},"id":"8f379155-6a0d-4db9-92e9-e1f745541a5c","type":"ToolEvents"},{"attributes":{"plot":{"id":"f8dba34a-3427-43cc-912e-3f9adbc56919","subtype":"Figure","type":"Plot"}},"id":"ee149ddd-b05d-4f78-a225-d0c55f2b98c5","type":"WheelZoomTool"},{"attributes":{"axis_label":"Power","formatter":{"id":"1efbf402-8a87-4a6a-bfec-8169c5a146d3","type":"BasicTickFormatter"},"plot":{"id":"f8dba34a-3427-43cc-912e-3f9adbc56919","subtype":"Figure","type":"Plot"},"ticker":{"id":"a4e699fe-dc0e-42f5-89fc-3bd909cb23f0","type":"BasicTicker"}},"id":"40e97c86-33d4-49d4-978c-0e3dcda1b477","type":"LinearAxis"},{"attributes":{},"id":"c85bfe5a-ab52-4572-bcbf-3468ae969410","type":"LogScale"},{"attributes":{"callback":null,"overlay":{"id":"60c560b2-4eed-4de3-9dd9-f4bb7628782e","type":"BoxAnnotation"},"plot":{"id":"f8dba34a-3427-43cc-912e-3f9adbc56919","subtype":"Figure","type":"Plot"},"renderers":[{"id":"009afcde-d64f-4873-aa0c-a1e9ca69041b","type":"GlyphRenderer"}]},"id":"c9a6c3fd-ca32-4146-9291-24a4f499a622","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"f8dba34a-3427-43cc-912e-3f9adbc56919","subtype":"Figure","type":"Plot"}},"id":"3b5268c0-dd14-4ca9-8355-107223acea59","type":"PanTool"},{"attributes":{},"id":"1efbf402-8a87-4a6a-bfec-8169c5a146d3","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"f8dba34a-3427-43cc-912e-3f9adbc56919","subtype":"Figure","type":"Plot"},"ticker":{"id":"a627636d-b24f-49b0-9f60-3cdba7462e21","type":"LogTicker"}},"id":"bfb64eff-49f3-4935-9d41-cddf4c5fd83e","type":"Grid"},{"attributes":{"below":[{"id":"7bc322da-c315-4eed-a22b-275bec5f28ad","type":"LogAxis"}],"left":[{"id":"40e97c86-33d4-49d4-978c-0e3dcda1b477","type":"LinearAxis"}],"renderers":[{"id":"7bc322da-c315-4eed-a22b-275bec5f28ad","type":"LogAxis"},{"id":"bfb64eff-49f3-4935-9d41-cddf4c5fd83e","type":"Grid"},{"id":"40e97c86-33d4-49d4-978c-0e3dcda1b477","type":"LinearAxis"},{"id":"a77690d2-f9de-428c-89e4-7a441715f238","type":"Grid"},{"id":"d68646b2-775a-490e-a247-de90a1975323","type":"BoxAnnotation"},{"id":"60c560b2-4eed-4de3-9dd9-f4bb7628782e","type":"BoxAnnotation"},{"id":"009afcde-d64f-4873-aa0c-a1e9ca69041b","type":"GlyphRenderer"}],"title":{"id":"0e4ca336-aaa3-466f-a3fa-3e ...
# Finding optimal frequency:
#  - Estimated peak width = 0.0169
#  - Using 5 steps per peak; omega_step = 0.00338
#  - User-specified period range:  0.1 to 32
#  - Computing periods at 18525 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# period = 1.78422287062

# %%
# t_bls - time is an N-dimensional array of timestamps for the light curve,
# f_bls - flux is the N-dimensional light curve array,
# qmi is the minimum transit duration to test, and
# qma is the maximum transit duration to test.
# fmin is the minimum frequency to test,
# df is the frequency grid spacing,
# nb is the number of bins to use in the folded light curve,
# nf is the number of frequency bins to test,
qmi = 0.06 #.02 is about 30 mins
qma = 0.3
fmin = round(1./max_period,2) #freq = 1/period
# fmin = 1/4.
df = 0.001 
nf = 1000
nb = 200

t_bls = t_detrend
f_bls = f_detrend
# f_bls = np.hstack(f_normalized)
# t_bls = np.hstack(t_median_smooth)
res = bls(t_bls, f_bls, qmi, qma, fmin, df, nf, nb)
print "Best SR: ", res[0], "\nIngress: ", res[1], "\nEgress: ", res[2], "\nq: ", res[3], \
"\nDepth: ", res[4], "\nPeriod: ", res[5], "\nSDE: ", res[6]


print "correct period: ", 3.568065
# Out:
# Best SR:  8.55617282112e-06
# Ingress:  122
# Egress:  140
# q:  0.095224073965
# Depth:  2.91498047967e-05
# Period:  3.57142857143
# SDE:  9.63663765057
# correct period:  3.568065

# %%
fmax = round(1./min_period,2) #freq = 1/period
steps = (fmax - fmin)/nf
freq = np.arange(fmin, fmax,steps)
plt.plot(freq, res[7], 'k.')
plt.title("SDE = {0}".format(res[6]))
plt.xlabel(r"Frequency (d$^{-1}$)")
plt.ylabel(r"$SR$")

# %%
t1 = t_bls[0]
#subtracts t0 from all times
u = t_bls - t1
#avg. flux
s = np.mean(f_bls)

#each flux point subtracted from mean of flux
# v = f_bls - s

## adjustment
#Better cause it shows percentage of change
v = f_bls/s

#plotting data
plt.plot(u, v, 'b.')
plt.title("Data Centering")
plt.xlabel(r"$t - t_0$, (days)")
plt.ylabel(r"$x(t) / \mu$, Flux")

# %%
#converting period to freq
f0 = 1.0/(res[5]) #  freq = 1/T
f0 = 1.0/3.568065
nbin = nb # number of bin
n = len(t_bls)
ibi = np.zeros(nbin)
y = np.zeros(nbin)
phase = np.linspace(-0.5, 0.5, nbin) 

t_fold = []
#this loop folds the data for each phase
for i in range(n):
    ph = u[i]*f0 #divides by period
    ph = ph - int(ph) # removes integer, ex. 5.2 ->> .2
    t_fold.append(ph-.5) #total data time fold
    
    #creates mean value of flux over time in a bin
    j = int(nbin*ph) # data to a bin 
    ibi[j] = ibi[j] + 1.0 # number of data in each bin
    y[j] = y[j] + v[i] # sum of light in a bin

mean_bin = y/ibi
through_center = np.argmin(mean_bin) #finds index of 
diff_center = nbin/2 - through_center #amount data needs to shift to get centered
mean_bin = np.roll(mean_bin, diff_center) #centers data
t_fold = np.roll(t_fold, -diff_center+11)
# f = np.hstack(f_detrend)
plt.plot(t_fold,v,'o', alpha=0.1)
plt.plot(phase, mean_bin, 'r.')
plt.title("Period: {0} d  bin: {1}".format(res[5], nbin))
plt.xlabel(r"Phase ($\phi$)")
plt.ylabel(r"Mean value of $x(\phi)$ in a bin")

# %%
plt.plot(phase, mean_bin, 'r.')

#bls fit
fit = np.ones(nbin) # H
# res[8] = high, res [9] = low
#uses ingress(res[1]), and engress(res[2]), to model expected results
engress = nbin/2 + (res[2] - res[1])/2 # engress bin number
ingress = nbin/2 - (res[2] - res[1])/2 # ingress bin number
trough = np.min(mean_bin) #model of the dip in the trough
fit[ingress:engress] = trough # adding model depth
    
print "Trough Value: ",trough
#added to adjust for new y axis scale
# fit = fit/s + 1

plt.plot(phase, fit)
plt.title("Period: {0} d  bin: {1}".format(res[5], nbin))
plt.xlabel(r"Phase ($\phi$)")
plt.ylabel(r"Mean value of $x(\phi)$ in a bin")
# Out:
# Trough Value:  0.999929248594

# %% [markdown]
# ## Radius of Planet

# %%
R_star = 1.35*R_sun # Star we are looking at
depth = 1-np.abs(trough) #depth of trough
R_planet = R_star*np.sqrt(depth) #finding radius of star
print R_planet/R_earth, 'Earth Radii'
print 'True answer: 1.29 Earth Radii'
# Out:
# 1.23825377754 Earth Radii
# True answer: 1.29 Earth Radii

# %% [markdown]
# # Ignore Everything Below Here

# %% [markdown]
# ## Method 2: Pyke Smoothing

# %% [markdown]
# Using pyke to median smooth all .fits lightcurves

# %%
# ###NOTE: if files exist already then delete or comment this part out


# #outputs median smooth .fits files
# for i in range(0,len(lightcurves)):

#     output_file = 'c:/Users/rscsa/Research/radvel-master/%d/smooth fits/%d_%d_%s'%(koi.kepid,koi.kepid,i,datacol)
#     print "Smoothing Quarter %d of Data:"%i
#     pyke.kepsmooth(lightcurves[i].filename,output_file,datacol=datacol)

# %% [markdown]
# Extracts all data from .fits files

# %%
# time_smooth, flux_smooth, ferr_smooth, quality_smooth = [], [], [], []
# for i in range(0,len(lightcurves)):
#     output_file = 'c:/Users/rscsa/Research/radvel-master/%d/smooth fits/%d_%d_%s'%(koi.kepid,koi.kepid,i,datacol)

#     hdulist = pyfits.open(output_file)
#     # hdulist.info()
#     hdu_data = hdulist[1].data
    
#     time_smooth.append(hdu_data["time"])
#     flux_smooth.append(hdu_data[datacol])
#     ferr_smooth.append(hdu_data["%s_ERR"%datacol])
#     quality_smooth.append(hdu_data["sap_quality"])

# %% [markdown]
# Plotting Pyke Smoothing

# %%
# # Time (BJD - 2454833)
# #Flux (e-/sec) + ____e+4
# #Which quarter do you want to look at?
# t1_smooth = time_smooth[quarter1]
# f1_smooth = flux_smooth[quarter1]
# t2_smooth = time_smooth[quarter2]
# f2_smooth = flux_smooth[quarter2]

# #Creating new plot with title and axis labels
# #Plot is an object
# lc_pykesmooth_265 = figure(
#     title=title, 
#     x_axis_label=x_label,
#     y_axis_label=y_label,
#     tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

# #adding x and y data and legend for plot
# lc_pykesmooth_265.circle(t1_smooth, f1_smooth,legend="Pyke Smooth Q%d"% quarter1)
# lc_pykesmooth_265.circle(t2_smooth, f2_smooth,legend="Pyke Smooth Q%d" % quarter2,color="red")

# # lc_pykesmooth_265.circle(t,f,legend=legend,fill_alpha = .2,line_alpha=.2)

# #showing results
# show(lc_pykesmooth_265)

# %%
# median1= (len(f1_smooth))/2
# f1_smooth_median =np.float64( "%f" % np.median(f1_smooth))
# f1_smooth_mean = np.mean(f1_smooth,dtype=np.float64)

# #make changes here if you want running average or median
# f1_smooth_normalized = f1_smooth/f1_smooth_mean

# median2= (len(f2_smooth))/2
# f2_smooth_median =np.float64( "%f" % np.median(f2_smooth))
# f2_smooth_mean = np.mean(f2_smooth,dtype=np.float64)

# #make changes here if you want running average or median
# f2_smooth_normalized = f2_smooth/f2_smooth_mean

# #combining data from two quarters
# f_smooth_normalized = np.append(f1_smooth_normalized, f2_smooth_normalized)
# t_smooth_no_outlier = np.append(t1_smooth, t2_smooth)

# %%
# #Creating new plot with title and axis labels
# #Plot is an object
# lc_pyke_normalized_265 = figure(
#     title=title, 
#     x_axis_label=x_label,
#     y_axis_label=y_label,
#     tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

# #adding x and y data and legend for plot
# lc_pyke_normalized_265.circle(t1_smooth, f1_smooth_normalized,legend="Pyke Normalized Q%d"% quarter1)
# lc_pyke_normalized_265.circle(t2_smooth, f2_smooth_normalized,legend="Pyke Normalized Q%d" % quarter2,color="red")

# # lc_pykesmooth_265.circle(t,f,legend=legend,fill_alpha = .2,line_alpha=.2)

# #showing results
# show(lc_pyke_normalized_265)

# %%
# period1 = periodogram(t_smooth_no_outlier,f_smooth_normalized,min_period,max_period,nyquist)

# %% [markdown]
# Box Least Square

# %%
# median_smooth_file = 'c:/Users/rscsa/Research/radvel-master/%d/smooth fits/%d_%d_%s'%(koi.kepid,koi.kepid,quarter,datacol)
# output_file = 'c:/Users/rscsa/Research/radvel-master/%d/bls fits/%d_%d_%s'%(koi.kepid,koi.kepid,quarter,'bls')
# print "BLS on Quarter %d of Data:"%quarter

# # pyke.kepbls(lightcurves[quarter].filename,output_file,datacol=datacol,errcol=errcol)
# pyke.kepbls(median_smooth_file,output_file,datacol=datacol,errcol=errcol)

# %%
# # t_bls - time is an N-dimensional array of timestamps for the light curve,
# # f_bls - flux is the N-dimensional light curve array,
# # qmi is the minimum transit duration to test, and
# # qma is the maximum transit duration to test.
# # fmin is the minimum frequency to test,
# # df is the frequency grid spacing,
# # nb is the number of bins to use in the folded light curve,
# # nf is the number of frequency bins to test,

# t_bls = t_smooth_no_outlier
# f_bls = f_smooth_normalized
# res = bls(t_bls, f_bls, qmi, qma, fmin, df, nf, nb)
# print "Best SR: ", res[0], "\nIngress: ", res[1], "\nEgress: ", res[2], "\nq: ", res[3], \
# "\nDepth: ", res[4], "\nPeriod: ", res[5], "\nSDE: ", res[6]


# print "correct period: ", 3.568065

# %% [markdown]
# Plotting BLS Results

# %%
# fmax = round(1./min_period,2) #freq = 1/period
# steps = (fmax - fmin)/nf
# freq = np.arange(fmin, fmax,steps)
# plt.plot(freq, res[7], 'k.')
# plt.title("SDE = {0}".format(res[6]))
# plt.xlabel(r"Frequency (d$^{-1}$)")
# plt.ylabel(r"$SR$")

# %% [markdown]
# ## Data centering
# Divide flux with the average value

# %%
# t1 = t_bls[0]
# #subtracts t0 from all times
# u = t_bls - t1
# #avg. flux
# s = np.mean(f_bls)

# #each flux point subtracted from mean of flux
# # v = f_bls - s

# ## adjustment
# #Better cause it shows percentage of change
# v = f_bls/s

# #plotting data
# plt.plot(u, v, 'b.')
# plt.title("Data Centering")
# plt.xlabel(r"$t - t_0$, (days)")
# plt.ylabel(r"$x(t) - \mu$, Flux")

# %% [markdown]
# ## Folded and binned
# If we fold the data with correct period and binned to 300 bins

# %%
# #converting period to freq
# f0 = 1.0/(res[5]) #  freq = 1/T
# nbin = nb # number of bin
# n = len(t_bls)
# ibi = np.zeros(nbin)
# y = np.zeros(nbin)
# phase = np.linspace(-0.5, 0.5, nbin) 

# #this loop folds the data for each phase
# for i in range(n):
#     ph = u[i]*f0 #divides by period
#     ph = ph - int(ph) # removes integer, ex. 5.2 ->> .2
    
#     #creates mean value of flux over time in a bin
#     j = int(nbin*ph) # data to a bin 
#     ibi[j] = ibi[j] + 1.0 # number of data in each bin
#     y[j] = y[j] + v[i] # sum of light in a bin
    
# mean_bin = y/ibi
# through_center = np.argmin(mean_bin) #finds index of 
# diff_center = nbin/2 - through_center
# mean_bin = np.roll(mean_bin, diff_center) #centers data

# plt.plot(phase, mean_bin, 'r.')
# plt.title("Period: {0} d  bin: {1}".format(res[5], nbin))
# plt.xlabel(r"Phase ($\phi$)")
# plt.ylabel(r"Mean value of $x(\phi)$ in a bin")

# %% [markdown]
# ## Fitted to the BLS result
# Folded with correct trial period and fit it with the BLS results.

# %%
# plt.plot(phase, mean_bin, 'r.')

# #bls fit
# fite = np.ones(nbin) # H
# # res[8] = high, res [9] = low
# #uses ingress(res[1]), and engress(res[2]), to model expected results
# engress = nbin/2 + (res[2] - res[1])/2 # engress bin number
# ingress = nbin/2 - (res[2] - res[1])/2 # ingress bin number
# trough = np.min(mean_bin) #model of the dip in the trough
# fite[ingress:engress] = trough # adding model depth

# #added to adjust for new y axis scale
# # fite = fite/s + 1

# plt.plot(phase, fite)
# plt.title("Period: {0} d  bin: {1}".format(res[5], nbin))
# plt.xlabel(r"Phase ($\phi$)")
# plt.ylabel(r"Mean value of $x(\phi)$ in a bin")

# %%
# import pandas as pd
# data= pd.read_csv("KOI-265.csv")
# t_detrend1 = np.array(data.BJD)
# f_detrend1= np.array(data.Detrend)

# %%
# #Plot is an object
# lc_detrend_265 = figure(
#     title= title, 
#     x_axis_label= x_label,
#     y_axis_label=y_label,
#     tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

# #adding x and y data for plot
# lc_detrend_265.circle(t_detrend1, f_detrend1,legend='Detrend Flux',color='green')
# # lc_detrend_265.circle(t_no_outlier,normal_normalized,legend='Normalized Flux',fill_alpha = .2,line_alpha=.2)
# show(lc_detrend_265)

# %%
# #using pyfits to open a quarter of data as .fits file
# pyfits.open('c:/Users/rscsa/.kplr/data/lightcurves/010874614/kplr010874614-2009131105131_llc.fits')
# print pyfits.hdu.image.PrimaryHDU()
