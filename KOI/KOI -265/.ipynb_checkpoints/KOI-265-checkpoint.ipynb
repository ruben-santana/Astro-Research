# %% [markdown]
# # Importing Module

# %%
#kplr used to import koi data easier
import kplr
client = kplr.API()

#used to open .fits files
import pyfits
# import astropy

#Used for Plotting
#Experimenting with this instead of using matplot.lib
from bokeh.plotting import figure, show, output_file,output_notebook
#Allows for viewing of plots on jupyter notebooks
output_notebook()

#For Maximum Likelihood
from scipy import optimize

#Used for scientific computing
import numpy as np

#For making copies of data
import copy

#Needed to correct median with 'nan' data points
import math

#For Periodogram
from gatspy.periodic import LombScargleFast

#Importing and notebook setup
# %matplotlib inline

#For Plotting
import matplotlib.pyplot as plt

#adjusting data using pyke
import pyke

#for astro constants
from astropy.constants import *

#needed for bls function
import math
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="64ecb7c3-59bc-471b-bcc1-a9756a5dfe23">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Making useful functions

# %% [markdown]
# Median Smooth

# %%
#Making loop to get Median Smooth
 
#jump - The number of pixels you are taking the median
### ex. jump = 7, median over 7 points, replaces values inbetween with median
### Before: [1,2,3,4,5,6,7]
### After:  [1,4,4,4,4,4,7]

#delta_min - delta between pixels must be less than this to be smoothed
#max_flux - anything above max_flux is smoothed out with median
#### used to keep peaks unchanged

def median_smooth(flux,jump,delta_max,max_flux):
    #n - determines section of data we are looking at
    n = 1
    
    #Data that is being changed and smoothed
    smooth_flux = copy.copy(flux)

    #median smoothing loop
    while n <= len(smooth_flux)-jump-1:    
        #delta of data from one point to another
        #used in for loop to leave troughs unchanged
        max_change = 0
        increase = False
        #Checks the max delta of data points for each jump
        for i in range (n-1,n+jump-1):
            delta = abs( flux[i]-flux[i+1])
            delta = flux[i]-flux[i+1]
            if delta > max_change:
                max_change = delta
            if flux[i] > max_flux:
                increase = True
        #Makes pixels in range equal to median
        if max_change < delta_max:
            median = np.median(flux[n-1:n+jump])
            
            #This line corrects errors with data labeled at 'nan' creates an 'nan' median
            if math.isnan(median)==False:
                smooth_flux[n:n+jump-2] = median

        #removes increases in flux
        if increase == True:
            median = np.median(flux[n-1:n+jump])
            smooth_flux[n:n+jump-2] = median

        #Loop counter
        n=n+jump

    return smooth_flux

# %% [markdown]
# Removing "nan" Flux Data Points

# %%
#Removes nan data points
def remove_nan(datax,datay):
    #array of nan points location in flux array
    nan_points=np.array([])
    
    #finds points that have nan as data point
    for j in range(0,len(datax)-1):
        if math.isnan(datay[j])==True:
            nan_points = np.append(nan_points,j)
    
    #deletes the points with nan and correspoding time
    datax = np.delete(datax,nan_points)
    datay = np.delete(datay,nan_points)
        
    return(datax,datay)

# %% [markdown]
# Removing Outliers

# %%
#datax - time data
#datay - flux data
#cutoff - flux larger than this value get removed
def remove_outlier(datax, datay, cutoff):
    outlier_points = np.array([])
    
    for i in range(0,len(datay)-1):
        if f[i]>cutoff:
            outlier_points = np.append(outlier_points,i)

    print outlier_points
    #deletes the points with nan and correspoding time
    datax = np.delete(datax,outlier_points)
    datay = np.delete(datay,outlier_points)
    
    return (datax, datay)

# %% [markdown]
# Lists all Outliers

# %%
#datay - flux
#maxdelta - max change from points to not be considered an outlier
def list_outliers(datay, maxdelta):
    
    outlier_points = np.array([])
    for i in range(1,len(datay)):
        delta = datay[i] - datay[i-1]
        
        if delta > maxdelta:
            a = int(i)
            outlier_points = np.append(outlier_points,a)
    
    return outlier_points

# %% [markdown]
# Periodograms

# %%
######Lomb-Scargle Periodogram##########

# Used to find periodic activity of star 
### Works only if you remove "nan" data points
#1st argument: time data
#2nd argument: flux data
#3rd argument: range minimum for finding period
#4th argument: range maximum for finding period
#5th argument: time between data points
def periodogram(datax, datay, min_per, max_per, nyquist):
    #finding periodogram
    model = LombScargleFast().fit(datax, datay)
    period, power = model.periodogram_auto(nyquist_factor=nyquist)

    #Plotting
    periodogram = figure(
        x_axis_label="Period",
        x_axis_type="log",
        y_axis_label="Period",
        tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

    #adding x and y data for plot
    periodogram.line(period,power)

    #showing results
    show(periodogram)

    # set range and find period
    model.optimizer.period_range=(min_per, max_per)
    period = model.best_period
    print("period = {0}".format(period))
    return period

# %%
#My own method of finding periods
#### Only works for clear periodiotic drops in flux
### Step 1: Make a cut_off and only look at that data
### Step 2: Find min flux of each trough
### Step 3: Find the avg. time diff between each local min
###Still need to makes this plot into a function and then will place it up above

#1st Argument: Flux Data
#2nd Argument: cut_off for troughs that get counted

def find_period(flux,cut_off):
    # cut_off is the max the point can be to pass the filter
    # f_change - change in flux from cutoff

    min_f = np.array([])
    min_t = np.array([])

    #Step 1: filters data to just the points below the cut_off
    for i in range(0,len(flux)):
        f_change = flux[i] - cut_off

        #checks if it's lower than cut off
        if f_change < 0:
            min_f = np.append(min_f,[flux[i]])
            min_t = np.append(min_t,[t[i]])

    # print min_f
    # print min_t

    #local_min - lowest point of troughs place holder
    #check - checks to see if new point is lower than previous local_min
    local_min = min_f[0]
    ndata = 0
    troughs_f = np.array([])
    troughs_t = np.array([])

    #Step 2: filters to just show only the lowest point of each trough
    for i in range(0,len(min_f)-1):
        t_change = min_t[i+1] - min_t[i]
        check = min_f[i]
        # checks if it's lower than previous local_min
        if check < local_min:
            local_min = check
            ndata = i

        #documents lowest point of each trough and resets check for next trough
        #t_change: checks time seperation between points to distinguish two seperate troughs, 
        #          can also be seen as min period it looks for
        if t_change > .5 or i > len(min_f)-3:
            troughs_f = np.append(troughs_f, [local_min])
            troughs_t = np.append(troughs_t, [min_t[ndata]])
            local_min = cut_off

    # print 'The min of each flux trough: ', troughs_f
    # print 'The corresponding time for each trough: ' ,troughs_t

    all_periods = np.array([])

    #Step 3: finding average change in time from each trough
    for i in range(0,len(troughs_t)-1):
        period = troughs_t[i+1]-troughs_t[i]
        all_periods = np.append(all_periods,period)

    avg_period = np.mean(all_periods,dtype=np.float64)
    print 'All periods: ', all_periods
    print 'Avg. period: ', avg_period, ' days.'

    return avg_period

# %% [markdown]
# BLS Function

# %%
#### Copying code from: https://ridlow.wordpress.com/category/ipython-notebook/

# t - time is an N-dimensional array of timestamps for the light curve,
# x - flux is the N-dimensional light curve array,
# qmi is the minimum transit duration to test, and
# qma is the maximum transit duration to test.
# fmin is the minimum frequency to test,
# df is the frequency grid spacing,
# nb is the number of bins to use in the folded light curve,
# nf is the number of frequency bins to test,

def bls(t, x, qmi, qma, fmin, df, nf, nb):
    """Frist trial, BLS algorithm, only minor modification from author's code"""
    
    n = len(t); rn = len(x)
    #! use try
    if n != rn:
        print "Different size of array, t and x"
        return 0

    rn = float(rn) # float of n

    minbin = 5
    nbmax = 2000
    if nb > nbmax:
        print "Error: NB > NBMAX!"
        return 0

    tot = t[-1] - t[0] # total time span

    if fmin < 1.0/tot:
        print "Error: fmin < 1/T"
        return 0

    # parameters in binning (after folding)
    kmi = int(qmi*nb) # nb is number of bin -> a single period
    if kmi < 1: 
        kmi = 1
    kma = int(qma*nb) + 1
    kkmi = rn*qmi # to check the bin size
    if kkmi < minbin: 
        kkmi = minbin

    # For the extension of arrays (edge effect: transit happen at the edge of data set)
    nb1 = nb + 1
    nbkma = nb + kma
        
    # Data centering
    t1 = t[0]
    u = t - t1
    s = np.mean(x) # ! Modified
    v = x - s

    bpow = 0.0
    p = np.zeros(nf)
    # Start period search
    for jf in range(nf):
        f0 = fmin + df*jf # iteration in frequency not period
        p0 = 1.0/f0

        # Compute folded time series with p0 period
        ibi = np.zeros(nbkma)
        y = np.zeros(nbkma)
        for i in range(n):
            ph = u[i]*f0 # instead of t mod P, he use t*f then calculate the phase (less computation)
            ph = ph - int(ph)
            j = int(nb*ph) # data to a bin 
            ibi[j] = ibi[j] + 1 # number of data in a bin
            y[j] = y[j] + v[i] # sum of light in a bin
        
        # Extend the arrays  ibi()  and  y() beyond nb by wrapping
        for j in range(nb1, nbkma):
            jnb = j - nb
            ibi[j] = ibi[jnb]
            y[j] = y[jnb]

        # Compute BLS statictics for this trial period
        power = 0.0

        for i in range(nb): # shift the test period
            s = 0.0
            k = 0
            kk = 0
            nb2 = i + kma
            # change the size of test period (from kmi to kma)
            for j in range(i, nb2): 
                k = k + 1
                kk = kk + ibi[j]
                s = s + y[j]
                if k < kmi: continue # only calculate SR for test period > kmi
                if kk < kkmi: continue # 
                rn1 = float(kk)
                powo = s*s/(rn1*(rn - rn1))
                if powo > power: # save maximum SR in a test period
                    power = powo # SR value
                    jn1 = i # 
                    jn2 = j
                    rn3 = rn1
                    s3 = s

        power = math.sqrt(power)
        p[jf] = power

        if power > bpow:
            bpow = power # Save the absolute maximum of SR
            in1 = jn1
            in2 = jn2
            qtran = rn3/rn
            # depth = -s3*rn/(rn3*(rn - rn3))
            # ! Modified
            high = -s3/(rn - rn3)
            low = s3/rn3
            depth = high - low
            bper = p0
    
    # ! add
    sde = (bpow - np.mean(p))/np.std(p) # signal detection efficiency

    return bpow, in1, in2, qtran, depth, bper, sde, p, high, low

# %% [markdown]
# # Beginning to Look at Data

# %% [markdown]
# Importing Data

# %%
# Find a KOI.
koi = client.koi(265.01)

#period, period error (postive & negative)
# print 'Period w/ errors: ',(koi.koi_period, koi.koi_period_err1, koi.koi_period_err2)

# This KOI has an associated star.
# star = koi.star
# print star
# print "Associated Star Temperature: ",(star.kic_teff)

#Download the lightcurves for this KOI.
lightcurves = koi.get_light_curves(short_cadence=False)
# for lc in lightcurves:
#     print (lc.filename)
print "Kepler ID ", koi.kepid
# Out:
# Kepler ID  12024120

# %% [markdown]
# Getting Like Curve Data

# %%
# Loop over the datasets and read in the data.
#Open the FITS data file and return the ``pyfits.HDUList``. This will
#download the file if it isn't already saved locally.
datacol = "PDCSAP_FLUX"
errcol = "PDCSAP_FLUX_ERR"
time, flux, ferr, quality = [], [], [], []
for lc in lightcurves:
    with lc.open() as f:
        # The lightcurve data are in the first FITS HDU.
        #can also append "SAP_Flux
        hdu_data = f[1].data
        time.append(hdu_data["time"])
        flux.append(hdu_data[datacol])
        ferr.append(hdu_data[errcol])
        quality.append(hdu_data["sap_quality"])

# %% [markdown]
# Initial Plot of Data

# %%
# Time (BJD - 2454833)
#Flux (e-/sec) + ____e+4
#Which quarter do you want to look at?
quarter = 9
t = time[quarter]
f = flux[quarter]
BJD = 245833
#Following Labels are used for all graphs
x_label = 'Time (BJD - %d)' %BJD
y_label = 'Flux(e-/sec)'
title = 'Kepler ID: %d, Quarter: %d'%(koi.kepid, quarter)


#Creating new plot with title and axis labels
#Plot is an object
lc_plot_265 = figure(
    title=title, 
    x_axis_label=x_label,
    y_axis_label=y_label,
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
legend = 'Quarter %d' % quarter
lc_plot_265.circle(t, f,legend=legend)

#showing results
show(lc_plot_265)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="de0dffcc-20f4-4548-bee1-e1e4428e762a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("de0dffcc-20f4-4548-bee1-e1e4428e762a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("de0dffcc-20f4-4548-bee1-e1e4428e762a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'de0dffcc-20f4-4548-bee1-e1e4428e762a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2547ccbf-589e-47b6-b8e0-923d7a2a08d2":{"roots":{"references":[{"attributes":{"below":[{"id":"306fdb5f-8b74-477c-9541-df842fd8d572","type":"LinearAxis"}],"left":[{"id":"3638c649-4966-47aa-b577-17189e68495f","type":"LinearAxis"}],"renderers":[{"id":"306fdb5f-8b74-477c-9541-df842fd8d572","type":"LinearAxis"},{"id":"100c7e67-9fa6-4855-830c-63b1552137dd","type":"Grid"},{"id":"3638c649-4966-47aa-b577-17189e68495f","type":"LinearAxis"},{"id":"b38a016d-3c80-4433-a1d7-499b25ea9723","type":"Grid"},{"id":"cae94894-f77f-434a-81c5-cde2d63ed684","type":"BoxAnnotation"},{"id":"114f70a9-e2ea-4469-a070-a92204a52d25","type":"BoxAnnotation"},{"id":"68ac188c-867e-4576-a1c1-47bfdd5ac297","type":"Legend"},{"id":"270c5099-9f94-4ffb-a5e3-e7829d381f68","type":"GlyphRenderer"}],"title":{"id":"03362230-be71-47ea-b397-8e500ce47ed4","type":"Title"},"tool_events":{"id":"95e351ca-bb70-4d09-b7f4-cfc7a45ea829","type":"ToolEvents"},"toolbar":{"id":"faa9dfbe-dbe3-4fd0
":"9379861d-811c-4409-be65-aaa6ad3bd5cd","type":"DataRange1d"},"x_scale":{"id":"71099e0d-58ed-4d53-97e7-fdb2f1370299","type":"LogScale"},"y_range":{"id":"44f39ae4-b0ad-4b3d-b606-9bf210fdf774","type":"DataRange1d"},"y_scale":{"id":"caf34d3d-3b0c-4d06-92eb-0d67d2d0d410","type":"LinearScale"}},"id":"9961e35b-7baf-4215-a11e-7aec4986a9b6","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"9961e35b-7baf-4215-a11e-7aec4986a9b6","subtype":"Figure","type":"Plot"}},"id":"3777cfc4-a00a-43c1-a9a4-228b63aa2a8e","type":"CrosshairTool"},{"attributes":{"plot":{"id":"9961e35b-7baf-4215-a11e-7aec4986a9b6","subtype":"Figure","type":"Plot"}},"id":"57773170-c331-4743-b4d9-5b1122e1dc38","type":"ResetTool"},{"attributes":{"data_source":{"id":"21078682-1703-4b18-8633-6d607c24302e","type":"ColumnDataSource"},"glyph":{"id":"cf71e04f-188c-479f-b223-b2b09a902ada","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4370a44b-2594-4f4e-bcb8-d269fc5a1d88","type":"Line"},"selection_glyph":null},"id":"dee25490-a4d3-4700-b1f0-08f18ada0ebe","type":"GlyphRenderer"},{"attributes":{},"id":"71099e0d-58ed-4d53-97e7-fdb2f1370299","type":"LogScale"},{"attributes":{},"id":"4ee6564c-1019-4500-998e-0131bfd76d4e","type":"BasicTicker"},{"attributes":{},"id":"ad929443-e7c6-4bae-96a2-ccd5811fbb67","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"9961e35b-7baf-4215-a11e-7aec4986a9b6","subtype":"Figure","type":"Plot"}},"id":"f0ea ...
# Finding optimal frequency:
#  - Estimated peak width = 0.0645
#  - Using 5 steps per peak; omega_step = 0.0129
#  - User-specified period range:  0.1 to 32
#  - Computing periods at 4856 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# period = 5.6835329421

# %% [markdown]
# ## Method 1: Pyke Smoothing

# %% [markdown]
# Using pyke to median smooth all .fits lightcurves

# %%
# ###NOTE: if files exist already then delete or comment this part out


# #outputs median smooth .fits files
# for i in range(0,len(lightcurves)):

#     output_file = 'c:/Users/rscsa/Research/radvel-master/%d/smooth fits/%d_%d_%s'%(koi.kepid,koi.kepid,i,datacol)
#     print "Smoothing Quarter %d of Data:"%i
#     pyke.kepsmooth(lightcurves[i].filename,output_file,datacol=datacol)

# %% [markdown]
# Extracts all data from .fits files

# %%
time_smooth, flux_smooth, ferr_smooth, quality_smooth = [], [], [], []
for i in range(0,len(lightcurves)):
    output_file = 'c:/Users/rscsa/Research/radvel-master/%d/smooth fits/%d_%d_%s'%(koi.kepid,koi.kepid,i,datacol)

    hdulist = pyfits.open(output_file)
    # hdulist.info()
    hdu_data = hdulist[1].data
    
    time_smooth.append(hdu_data["time"])
    flux_smooth.append(hdu_data[datacol])
    ferr_smooth.append(hdu_data["%s_ERR"%datacol])
    quality_smooth.append(hdu_data["sap_quality"])

# %% [markdown]
# Plotting Pyke Smoothing

# %%
# Time (BJD - 2454833)
#Flux (e-/sec) + ____e+4
#Which quarter do you want to look at?
t_smooth = time_smooth[quarter]
f_smooth = flux_smooth[quarter]

#Creating new plot with title and axis labels
#Plot is an object
lc_pykesmooth_265 = figure(
    title=title, 
    x_axis_label=x_label,
    y_axis_label=y_label,
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data and legend for plot
lc_pykesmooth_265.line(t_smooth, f_smooth,legend="Pyke Smooth",color="red")
lc_pykesmooth_265.circle(t,f,legend=legend,fill_alpha = .2,line_alpha=.2)

#showing results
show(lc_pykesmooth_265)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fb16ff17-2f97-49cc-aca6-b527ceadc3e6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fb16ff17-2f97-49cc-aca6-b527ceadc3e6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fb16ff17-2f97-49cc-aca6-b527ceadc3e6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fb16ff17-2f97-49cc-aca6-b527ceadc3e6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"be5f4aa8-e6c5-4327-acc8-94e7b4ae6342":{"roots":{"references":[{"attributes":{"callback":null,"overlay":{"id":"6709835d-df08-40d2-bf35-5316b1911720","type":"BoxAnnotation"},"plot":{"id":"251ae32d-335e-4c6a-bcf9-bc48ce13e552","subtype":"Figure","type":"Plot"},"renderers":[{"id":"c1b668f5-5900-472f-96b4-401733b64d99","type":"GlyphRenderer"},{"id":"57573a64-fcf6-4c7b-89f3-ae96fcda74c5","type":"GlyphRenderer"}]},"id":"b637b39b-6d65-49f7-a34e-1a5a3e0e8bde","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"251ae32d-335e-4c6a-bcf9-bc48ce13e552","subtype":"Figure","type":"Plot"}},"id":"ae72c53d-6d57-4219-a136-875c05d0dede","type":"PanTool"},{"attributes":{"plot":{"id":"251ae32d-335e-4c6a-bcf9-bc48ce13e552","subtype":"Figure","type":"Plot"}},"id":"655fffb1-18ac-466b-b096-b7a7a494a4b1","type":"CrosshairTool"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4eda5c8a-3b07-43b1-b028-cbaad2b14b62","type":"Line"},{"attributes":{"label":{"value":"Pyke Smooth"},"renderers":[{"id":"c1b668f5-5900-472f-96b4-401733b64d99","type":"GlyphRenderer"}]},"id":"47ae6a2d-0d50-4b47-b9b5-433761f821ac","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c2226b6e-118d-4bfa-9be4-8276c71bb90c","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"c2226b6e-118d-4bfa-9be4-8276c71bb90c","type":"BoxAnnotation"},"plot":{"id":"251ae32d-335e-4c6a-bcf9-bc48ce13e552","subtype":"Figure","type":"Plot"}},"id":"ea2cc591-17fb-45c7-aa8a-9dcf24deec81","type":"BoxZoomTool"},{"attributes":{"label":{"value":"Quarter 9"},"renderers":[{"id":"57573a64-fcf6-4c7b-89f3-ae96fcda74c5","type":"GlyphRenderer"}]},"id":"a4128007-1237-4e77-9b28-165a4001c446","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[808.5158192412418,808.5362531446226,808.5566870482362,808.5771209520753,808.5975548561546,808.6179888604674,808.6384227648887,808.6588565696657,808.679290574677,808.6997244799131,808.7201582853886,808.740592290982,808.7610261969166,808.7814600029742,808.8018940093752,808.8223279160156,808.8427619227732,808.8631957297621,808.8836296370937,808.904063544549,808.9244974523463,808.9449313602672,808.965365268421,808.9857991768076,809.0062331854206,809.0266669942721,809
type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d68e0d2e-5429-425e-8dc9-50647af76b90","type":"Line"},"selection_glyph":null},"id":"6ef5113c-7c4b-41eb-9e64-ccdb263e08b3","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9ca35442-392b-4eeb-b027-3a283336dd49","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d68e0d2e-5429-425e-8dc9-50647af76b90","type":"Line"},{"attributes":{"plot":null,"text":""},"id":"9a517514-8bc0-4664-94b7-56ad610ce530","type":"Title"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[230]},"y":{"__ndarray__":"...","dtype":"float64","shape":[230]}}},"id":"9537dc26-913a-4840-8f67-1477768abb68","type":"ColumnDataSource"},{"attributes":{"callback":null,"plot":{"id":"6e0172e8-0575-43f5-ac8d-c286333ddac2","subtype":"Figure","type":"Plot"}},"id":"d615a2db-3d2b-4aeb-adb0-5eca6d94b39a","type":"HoverTool"},{"attributes":{"callback":null,"overlay":{"id":"9ca35442-392b-4eeb-b027-3a283336dd49","type":"BoxAnnotation"},"plot":{"id":"6e0172e8-0575-43f5-ac8d-c286333ddac2","subtype":"Figure","type":"Plot"},"renderers":[{"id":"6ef5113c-7c4b-41eb-9e64-ccdb263e08b3","type":"GlyphRenderer"}]},"id":"0a8fa026-5a0e-4aa7-9a9a-136348e36312","type":"BoxSelectTool"},{"attributes":{"dimension":1,"plot":{"id":"6e0172e8-0575-43f5-ac8d-c286333ddac2","subtype":"Figure","type":"Plot"},"ticker":{"id":"842707d2-ed16-48b4-bc8d-9454ba737941","type":"BasicTicker"}},"id":"abe6c54c-462a-430c-aaa9-c26bcd44c266","type":"Grid"},{"attributes":{},"id":"236d9a6a-59ac-4d92-8afe-f29838367f2f","type":"LinearScale"},{"attributes":{},"id":"c7c0efe9-0e6e-4620-a7cd-0d0f06a34920","type":"LogScale"},{"attributes":{"num_minor_ticks":10},"id":"fcde2ae8-7eb6-4060-ad7f-90a9d6b308f2","type":"LogTicker"},{"attributes":{"axis_label":"Period","formatter":{"id":"22126dc4-2845-47bf-8f91-377e3327c70e","type":"LogTickFormatter"},"plot":{"id":"6e0172e8-0575-43f5-ac8d-c286333ddac2","subtype":"Figure","type":"Plot"},"ticker":{"id":"fcde2ae8-7eb6-4060-ad7f-90a9d6b308f2","type":"LogTicker"}},"id":"3df022aa-63fa-4580-bb87-246dc8ed0a05","type":"LogAxis"},{"attributes":{"callback":null,"plot":{"id":"6e0172e8-0575-43f5-ac8d-c286333ddac2","subtype":"Figure","type":"Plot"}},"id":"555cbb4e-ac28-4a21-96a2-db6e71a114c1","type":"TapTool"},{"attributes":{"plot":{"id":"6e0172e8-0575-43f5-ac8d-c286333ddac2","subtype":"Figure","type": ...
# Finding optimal frequency:
#  - Estimated peak width = 0.0645
#  - Using 5 steps per peak; omega_step = 0.0129
#  - User-specified period range:  0.1 to 32
#  - Computing periods at 4856 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# period = 12.7717651773

# %% [markdown]
# Box Least Square

# %%
# median_smooth_file = 'c:/Users/rscsa/Research/radvel-master/%d/smooth fits/%d_%d_%s'%(koi.kepid,koi.kepid,quarter,datacol)
# output_file = 'c:/Users/rscsa/Research/radvel-master/%d/bls fits/%d_%d_%s'%(koi.kepid,koi.kepid,quarter,'bls')
# print "BLS on Quarter %d of Data:"%quarter

# # pyke.kepbls(lightcurves[quarter].filename,output_file,datacol=datacol,errcol=errcol)
# pyke.kepbls(median_smooth_file,output_file,datacol=datacol,errcol=errcol)
# Out:
# BLS on Quarter 9 of Data:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1001/1001 [06:26<00:00,  2.57it/s]
#       Best trial period = 29.1300430298 days
#     Time of mid-transit = BJD 2455658.5482
#        Transit duration = 2.42750358582 hours
#  Maximum signal residue = 0.814070666151

# %%
# t_bls - time is an N-dimensional array of timestamps for the light curve,
# f_bls - flux is the N-dimensional light curve array,
# qmi is the minimum transit duration to test, and
# qma is the maximum transit duration to test.
# fmin is the minimum frequency to test,
# df is the frequency grid spacing,
# nb is the number of bins to use in the folded light curve,
# nf is the number of frequency bins to test,

qmi = 0.06 #.02 is about 30 mins
qma = 0.3
fmin = round(1./max_period,2) #freq = 1/period
fmin = 1/4.
df = 0.001 
nf = 1000
nb = 200
t_bls = t_smooth
f_bls = f_smooth
res = bls(t_bls, f_bls, qmi, qma, fmin, df, nf, nb)
print "Best SR: ", res[0], "\nIngress: ", res[1], "\nEgress: ", res[2], "\nq: ", res[3], \
"\nDepth: ", res[4], "\nPeriod: ", res[5], "\nSDE: ", res[6]


print "correct period: ", 3.568065
# Out:
# Best SR:  1.25280873315
# Ingress:  170
# Egress:  228
# q:  0.284598698482
# Depth:  -2.77647299898
# Period:  3.90625
# SDE:  4.52543846613
# correct period:  3.568065

# %% [markdown]
# Plotting BLS Results

# %%
fmax = round(1./min_period,2) #freq = 1/period
steps = (fmax - fmin)/nf
freq = np.arange(fmin, fmax,steps)
plt.plot(freq, res[7], 'k.')
plt.title("SDE = {0}".format(res[6]))
plt.xlabel(r"Frequency (d$^{-1}$)")
plt.ylabel(r"$SR$")

# %% [markdown]
# ## Data centering
# Divide flux with the average value

# %%
t1 = t_bls[0]
#subtracts t0 from all times
u = t_bls - t1
#avg. flux
s = np.mean(f_bls)

#each flux point subtracted from mean of flux
# v = f_bls - s

## adjustment
#Better cause it shows percentage of change
v = f_bls/s

#plotting data
plt.plot(u, v, 'b.')
plt.title("Data Centering")
plt.xlabel(r"$t - t_0$, (days)")
plt.ylabel(r"$x(t) - \mu$, Flux")

# %% [markdown]
# ## Folded and binned
# If we fold the data with correct period and binned to 300 bins

# %%
#converting period to freq
f0 = 1.0/(res[5]) #  freq = 1/T
# f0 = 1.0/3.568065   #±3e-05
nbin = nb # number of bin
n = len(t_bls)
ibi = np.zeros(nbin)
y = np.zeros(nbin)
phase = np.linspace(0.0, 1.0, nbin) 

#this loop folds the data for each phase
for i in range(n):
    ph = u[i]*f0 #divides by period
    ph = ph - int(ph) # removes integer, ex. 5.2 ->> .2
    
    #creates mean value of flux over time in a bin
    j = int(nbin*ph) # data to a bin 
    ibi[j] = ibi[j] + 1.0 # number of data in a bin
    y[j] = y[j] + v[i] # sum of light in a bin


plt.plot(phase, y/ibi, 'r.')
plt.title("Period: {0} d  bin: {1}".format(res[5], nbin))
plt.xlabel(r"Phase ($\phi$)")
plt.ylabel(r"Mean value of $x(\phi)$ in a bin")

# %% [markdown]
# ## Fitted to the BLS result
# Folded with correct trial period and fit it with the BLS results.

# %%
plt.plot(phase, y/ibi, 'r.')

#bls fit
fite = np.zeros(nbin) + res[8] # H
#uses ingress(res[1]), and engress(res[2]), to model expected results
fite[res[1]:res[2]+1] = res[9] # L

#added to adjust for throughs being cut off
if res[2] > nbin:
    first_trough = (res[2]-res[1]) - (nbin-res[1])
    fite[0:first_trough] = res[9]
    
#added to adjust for new y axis scale
fite = fite/s + 1

plt.plot(phase, fite)
plt.title("Period: {0} d  bin: {1}".format(res[5], nbin))
plt.xlabel(r"Phase ($\phi$)")
plt.ylabel(r"Mean value of $x(\phi)$ in a bin")

# %% [markdown]
# # Method 2: Removing "nan" Data points and outliers, then Median Smoothing of Data

# %% [markdown]
# Changes needed for each quarter

# %%
#median smooth
npixel = 20 # one pixel 30mins
maxdelta = 60
maxflux = 2.25e+5
f_no_nan_smooth = median_smooth(f_no_nan,npixel,maxdelta,maxflux)

# %%
#Plot is an object
lc_no_nan_265 = figure(
    title= title, 
    x_axis_label= x_label,
    y_axis_label=y_label,
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
lc_no_nan_265.line(t_no_nan, f_no_nan_smooth,legend='Median Smooth and no NAN Data',color='green')
lc_no_nan_265.circle(t,f,legend=legend,fill_alpha = .2,line_alpha=.2)
show(lc_no_nan_265)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bbf09c0b-1c49-4ac9-b367-e9f7fc5fd31e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bbf09c0b-1c49-4ac9-b367-e9f7fc5fd31e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bbf09c0b-1c49-4ac9-b367-e9f7fc5fd31e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bbf09c0b-1c49-4ac9-b367-e9f7fc5fd31e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dca7d6c6-215d-4963-aea6-d3f36aadfae3":{"roots":{"references":[{"attributes":{"plot":null,"text":"Kepler ID: 12024120, Quarter: 9"},"id":"b326612f-46a8-4ca7-a2a9-cc82d79da096","type":"Title"},{"attributes":{"plot":{"id":"eea0ef45-96f4-4d66-ac9f-4b4352cd2e01","subtype":"Figure","type":"Plot"}},"id":"c9b47de7-ea8e-4036-9bc4-dba312b586ff","type":"CrosshairTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"789282dd-d7ad-4ddc-aefa-49dc68c55c1c","type":"BoxAnnotation"},{"attributes":{},"id":"b6bdf084-ab50-4829-97b5-283746ebf632","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[808.5362531446226,808.5566870482362,808.5771209520753,808.5975548561546,808.6179888604674,808.6384227648887,808.6588565696657,808.679290574677,808.6997244799131,808.7201582853886,808.740592290982,808.7610261969166,808.7814600029742,808.8018940093752,808.8223279160156,808.8427619227732,808.8631957297621,808.8836296370937,808.904063544549,808.9244974523463,808.9449313602672,808.965365268421,808.9857991768076,809.0062331854206,809.0266669942721,809.0471009034663,809.067534912785,809.0879687223351,809.1084026320023,809.1288366420122,809.1492704522607,809.1697043627355,809.1901383734512,809.2105722842825,809.2310061954558,809.2514401068693
1f47b16fd8f7","type":"LogTicker"}},"id":"a292cc98-f873-4a60-bc32-f65b77938a58","type":"LogAxis"},{"attributes":{"num_minor_ticks":10},"id":"5619b2a8-d43a-43a8-9a40-1f47b16fd8f7","type":"LogTicker"},{"attributes":{"callback":null,"plot":{"id":"a317b210-01f0-49bd-8ce3-45419a74ffae","subtype":"Figure","type":"Plot"}},"id":"d489af1c-42bd-445f-8429-7c9d16929295","type":"HoverTool"},{"attributes":{"plot":{"id":"a317b210-01f0-49bd-8ce3-45419a74ffae","subtype":"Figure","type":"Plot"},"ticker":{"id":"5619b2a8-d43a-43a8-9a40-1f47b16fd8f7","type":"LogTicker"}},"id":"b9a1e3e1-47fa-4eb2-931d-f4defbe9685c","type":"Grid"},{"attributes":{"plot":{"id":"a317b210-01f0-49bd-8ce3-45419a74ffae","subtype":"Figure","type":"Plot"}},"id":"b67d2dc7-d7ec-454c-8e6f-e0d4fa5c8fbd","type":"PanTool"},{"attributes":{"callback":null},"id":"987fddaf-c5d1-4f9b-b56f-46d29153fc27","type":"DataRange1d"},{"attributes":{},"id":"53e0fa29-0370-4091-ad36-28c7593f2ea1","type":"LinearScale"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3a7292c1-68eb-4ad1-a960-369306f65413","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"a317b210-01f0-49bd-8ce3-45419a74ffae","subtype":"Figure","type":"Plot"}},"id":"968c2fba-1285-429f-8770-86a3e3eca155","type":"SaveTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f3ee494-ef25-467d-9b7e-64bcf1b9dcad","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a6190c1d-95de-4de4-ad6b-cdc9963b5b5a","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"1b67403e-40c8-4b55-86de-8b0e8a6c7c47","type":"ColumnDataSource"},"glyph":{"id":"9f3ee494-ef25-467d-9b7e-64bcf1b9dcad","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a32e9f42-1cbb-428b-8169-ac1e60cd4883","type":"Line"},"selection_glyph":null},"id":"7f155f75-b6a4-4196-9632-2508b7daae31","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[230]},"y":{"__ndarray__":"...","dtype":"float64","shape":[230]}}},"id":"1b67403e-40c8-4b55-86de-8b0e8a6c7c47","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"3a7292c1-68eb-4ad1-a960-369306f65413","type":"BoxAnnotation"},"plot":{"id":"a317b210-01f0-49bd-8ce3-45419a74ffae","subtype":"Figure","type":"Plot"}},"id":"bc5a133d-1b0c-4399-98ca-b1412afe2ea3","type":"BoxZoomTool"},{"attributes":{},"id":"2a07b7f4-b152-4a20-854b-e2783fbb20c5","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"a317b210-01f0-49bd-8ce3-45419a74ffae","subtype":"Figure","type":"Plot"},"ticker":{"id":"2a07b7f4-b152-4a20-854b-e2783fbb20c5","type":"BasicTicker"}},"id":"38193984-4e4a-4b4b-a825-c7d3ef7274fb","type":"Grid"},{"attributes":{},"id":"821572bc-bd6b-4f89-b7c1-6841bf512e41","type":"ToolEvents"},{"attributes":{"plot":{"id":"a317b210-01f0-49bd-8c ...
# Finding optimal frequency:
#  - Estimated peak width = 0.0645
#  - Using 5 steps per peak; omega_step = 0.0129
#  - User-specified period range:  0.1 to 32
#  - Computing periods at 4856 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# period = 5.67359980454

# %%
#1st Argument: Flux Data
#2nd Argument: cut_off for troughs that get counted
trough_cutoff = 2.248e+5
period = find_period(f_no_nan_smooth,trough_cutoff)
# Out:
# All periods:  [ 6.13029196  6.31419664]
# Avg. period:  6.22224429806  days.

# %% [markdown]
# ## Method 3: Detrending Method, Running Average

# %% [markdown]
# Step 1: cleaning data, remove outliers and nan points

# %%
maxdelta = 50
list_outlier = list_outliers(f_no_nan,maxdelta)
# print list_outlier
f_no_outlier = np.delete(f_no_nan,list_outlier)
t_no_outlier = np.delete(t_no_nan,list_outlier)

# %%
#Plot is an object
lc_no_outlier_265 = figure(
    title= title, 
    x_axis_label= x_label,
    y_axis_label=y_label,
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
lc_no_outlier_265.circle(t_no_outlier, f_no_outlier,legend='Cleaned Flux',color='red')
lc_no_outlier_265.circle(t,f,legend=legend,fill_alpha = .2,line_alpha=.2)
show(lc_no_outlier_265)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e2d1a3a9-d530-441a-9b93-3682aeb9c7fb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e2d1a3a9-d530-441a-9b93-3682aeb9c7fb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e2d1a3a9-d530-441a-9b93-3682aeb9c7fb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e2d1a3a9-d530-441a-9b93-3682aeb9c7fb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7833cb35-87fe-40d2-a310-d5ade2eafe3e":{"roots":{"references":[{"attributes":{"plot":null,"text":"Kepler ID: 12024120, Quarter: 9"},"id":"c406b2e2-b706-4bac-889e-937ea882abb1","type":"Title"},{"attributes":{"plot":{"id":"e1d44b99-d54e-42d1-a71a-599e84e234ce","subtype":"Figure","type":"Plot"}},"id":"898a6cd9-afc9-4b54-8627-a92b36e0c866","type":"PanTool"},{"attributes":{"data_source":{"id":"e9a90f78-b991-4fc0-86b9-58bec8c6a102","type":"ColumnDataSource"},"glyph":{"id":"42c5ac75-d2b0-44b2-80dc-a7fa275f466d","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"abfb08b7-e62d-4039-8046-5abc3e29f207","type":"Circle"},"selection_glyph":null},"id":"235d4370-5087-4c16-a14f-ea068c717173","type":"GlyphRenderer"},{"attributes":{"axis_label":"Flux(e-/sec)","formatter":{"id":"ee60aed8-562b-4644-91b8-a879971bd5ed","type":"BasicTickFormatter"},"plot":{"id":"e1d44b99-d54e-42d1-a71a-599e84e234ce","subtype":"Figure","type":"Plot"},"ticker":{"id":"6b92adaf-9646-4e97-89f6-6a25e6b4c00d","type":"BasicTicker"}},"id":"7437d40d-c97d-4df8-bc5f-d2668748d271","type":"LinearAxis"},{"attributes":{},"id":"ee60aed8-562b-4644-91b8-a879971bd5ed","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"Cleaned Flux"},"renderers":[{"id":"235d4370-5087-4c16-a14f-ea068c717173","type":"GlyphRenderer"}]},"id":"1358076d-80bb-44af-9c74-ecbd35ffb312","type":"LegendItem"},{"attributes":{"below":[{"id":"ea2d4a90-0512-48ec-85f4-ffd890f9f0f7","type":"LinearAxis"}],"left":[{"id":"7437d40d-c97d-4df8-bc5f-d2668748d271","type":"LinearAxis"}],"renderers":[{"id":"ea2d4a90-0512-48ec-85f4-ffd890f9f0f7","type":"LinearAxis"},{"id":"2ab1bd8e-694a-423c-bdc7-a0c6f6acda00","type":"Grid"},{"id":"7437d40d-c97d-4df8-bc5f-d2668748d271","type":"LinearAxis"},{"id":"969a03cf-74de-4c56-ae59-3e8448454203","type":"Grid"},{"id":"71bfe512-7c35-4c4a-b636-a0b3d08fcdd2","type":"BoxAnnotation"},{"id":"4a8fc538-0b1c-4f35-9ad9-3c707b0c7127","type":"BoxAnnotation"},{"id":"0a0eff11-a9d1-45d2-a201-fbd09ee39835","type":"Legend"},{"id":"235d4370-5087-4c16-a14f-ea068c717173","type":"GlyphRenderer"},{"id":"87411e28-1f39-4eaf-b522-9bcc4ac4e5a7","type":"GlyphRenderer"}],"title":{"id":"c406b2e2-b706-4bac-889e-937ea882abb1","type":"Title"},"tool_events":{"id":"80c74fa0-bfab-43dd-9972-5249fc4fcf25","type":"ToolEvents"},"toolbar":{"id":"3e20fdd5-00c6-4fb0-a41d-9c6b1a68244f","type":"Toolbar"},"x_range":{"id":"0e459bce-fb37-40e7-9016-5f803f06a221","type":"DataRange1d"},"x_scale":{"id":"02462890-f94f-441a-b4c6-46da2e2855f1","type":"LinearScale"},"y_range":{"id":"6c636b64-8d85-40fa-8ece-b8b1fad57cf4","type":"DataRange1d"},"y_scale":{"id":"78f97fac-a8fb-4165-85e3-a2a65d0745b8","type":"LinearScale"}},"id":"e1d44b99-d54e-42d1-a71a-599e84e234ce","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"23a34f4e-4d2c-487e-abd3-0f9f92e3185d","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"Quarter 9"},"renderers":[{"id":"87411e28-1f39-4eaf-b522-9bcc4ac4e5a7","type":"GlyphRenderer"}]},"id":"c0c61e73-b032-453e-93c1-d21893572068","type":"LegendItem"},{"attributes":{"plot":{"id":"e1d44b99-d54e-42d1-a71a-599e84e234ce","subtype":"Figure","type":"Plot"}},"id":"094f7115-52c2-41e2-a520-1edc414ccf34","type":"SaveTool"},{"attributes":{"items":[{"id":"1358076d-80bb-44af-9c74-ecbd35ffb312","type":"LegendItem"},{"id":"c0c61e73-b032-453e-93c1-d21893572068","type":"LegendItem"}],"plot":{"id":"e1d44b99-d54e-42d1-a71a-599e84e234ce","subtype":"Figure","type":"Plot"}},"id":"0a0eff11-a9d1-45d2-a201-fbd09ee39835","type":"Legend"},{"attributes":{},"id":"80c74fa0-bfab-43dd-9972-5249fc4fcf25","type":"ToolEvents"},{"attributes":{"overlay":{"id":"71bfe512-7c35-4c4a-b636-a0b3d08fcdd2","type":"BoxAnnotation"},"plot":{"id":"e1d44b99-d54e-42d1-a71a-599e84e234ce","subtype":"Figure","type":"Plot"}},"id":"a3f1a5ec-efa8-4752-834b-a42ab5104066","type":"BoxZoomTool"},{"attributes":{},"id":"76d5eec4-9bac-49ab-a267-23ad2ddb8568","type":"BasicTicker"},{"attributes":{},"id":"02462890-f94f-441a- ...

# %% [markdown]
# Step 2:Normalize data

# %%
median= (len(f_no_outlier))/2
f_median =np.float64( "%f" % np.median(f_no_outlier))
f_mean = np.mean(f_no_outlier,dtype=np.float64)

#make changes here if you want running average or median
f_normalized = f_no_outlier/f_mean

# %%
#Plot is an object
lc_normal_265 = figure(
    title= title, 
    x_axis_label= x_label,
    y_axis_label=y_label,
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
lc_normal_265.circle(t_no_outlier, f_normalized,legend='Normalized Flux',color='green')
# lc_normal_265.circle(t,f,legend=legend,fill_alpha = .2,line_alpha=.2)
show(lc_normal_265)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1c759081-25f9-422a-9d2f-ce788cc5210f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1c759081-25f9-422a-9d2f-ce788cc5210f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1c759081-25f9-422a-9d2f-ce788cc5210f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1c759081-25f9-422a-9d2f-ce788cc5210f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a64a8f0f-8d51-4e96-aa48-30279ff75abf":{"roots":{"references":[{"attributes":{"label":{"value":"Normalized Flux"},"renderers":[{"id":"6817323b-7399-46d7-8447-fcd682443332","type":"GlyphRenderer"}]},"id":"51c50bff-3e96-4da9-a451-b9f18cba7e96","type":"LegendItem"},{"attributes":{"below":[{"id":"1854b1c7-2169-45c6-af03-9f3612852c13","type":"LinearAxis"}],"left":[{"id":"907d907a-f0f8-4ad9-8a9a-e02aa2e0b729","type":"LinearAxis"}],"renderers":[{"id":"1854b1c7-2169-45c6-af03-9f3612852c13","type":"LinearAxis"},{"id":"6ff3e1a3-21ab-4fd3-9720-6a983856127b","type":"Grid"},{"id":"907d907a-f0f8-4ad9-8a9a-e02aa2e0b729","type":"LinearAxis"},{"id":"493e4d93-1b84-43d3-abb2-f16c87578587","type":"Grid"},{"id":"1476b86e-df97-4f1c-9887-7ba0b22eaec4","type":"BoxAnnotation"},{"id":"fe9d6823-2c77-411d-9547-dba24ba57f34","type":"BoxAnnotation"},{"id":"6b4436e7-a74f-453a-a14d-3ba90e715810","type":"Legend"},{"id":"6817323b-7399-46d7-8447-fcd682443332","type":"GlyphRenderer"}],"title":{"id":"7488151a-f0bb-467d-8ab6-a55455323b6a","type":"Title"},"tool_events":{"id":"68cbf1b5-7780-4228-9364-41e2fe82fd7a","type":"ToolEvents"},"toolbar":{"id":"f501e29f-b7bc-412f-94bd-2551e243a00d","type":"Toolbar"},"x_range":{"id":"d1a0bdab-b3d8-4970-bc4b-7c6425c1aab2","type":"DataRange1d"},"x_scale":{"id":"f561c565-9b39-41c2-a07a-a672ede8d685","type":"LinearScale"},"y_range":{"id":"6005181c-bf56-488f-80e4-d2646ebbf272","type":"DataRange1d"},"y_scale":{"id":"f4bc49ed-fcbe-48b7-9e3c-1baa5b429447","type":"LinearScale"}},"id":"34bef442-0720-4dcb-bb01-c2e829688f6b","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"bdbd1660-2c40-40be-9b67-a52776ec678a","type":"ColumnDataSource"},"glyph":{"id":"ed3ed8a8-2b6e-42bd-a00a-4c7168c25c65","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"57438e95-3929-4c37-9e2e-dedf86331b97","type":"Circle"},"selection_glyph":null},"id":"6817323b-7399-46d7-8447-fcd682443332","type":"GlyphRenderer"},{"attributes":{},"id":"cc5cdbf9-b8d5-40fc-8893-bc2cfa0c73f4","type":"BasicTicker"},{"attributes":{},"id":"f4bc49ed-fcbe-48b7-9e3c-1baa5b429447","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[808.5362531446226,808.5566870482362,808.5771209520753,808.5975548561546,808.6179888604674,808.6384227648887,808.6588565696657,808.679290574677,808.6997244799131,808.7201582853886,808.740592290982,808.7610261969166,808.7814600029742,808.8018940093752,808.8223279160156,808.8427619227732,808.8631957297621,808.8836296370937,808.904063544549,808.9244974523463,808.9449313602672,808.965365268421,808.9857991768076,809.0062331854206,809.0266669942721,809.0471009034663,809.067534912785,809.0879687223351,809.1084026320023,809.1288366420122,809.1492704522607,809.1697043627355,809.1901383734512,809.2310061954558,809.2514401068693,809.2718740183991,809.2923079302709,809.3127418422664,809.3331757546111,809.3536097670658,809.374043579759,809.3944775926866,809.4149115059554,809.4353453193471,809.4557793329732,809.476213246824,809.4966470609143,809.5170810752388,809.5375149897882,809.5579488045769,809.5783828194835,809.5988166347306,809.6192506502193,809.6396845658237,809.6601183817693,809.6805523978401,809.7009863142594,809.7214202307878,809.7418541475563,809.7622880646741,809.782721981901,809.803155899368,809.8235898170678,809.844023834994,809.8644577531595,809.8848915715571,809.9053255901817,809.9257595090457,809.9461933280254,809.9666273473485,809.987061266911,810.0074952865834,810.0279291066108,810.0483630267554,810.0687970471263,810.0892308678522,810.1096647886952,810.1300988097646,810.1505326310726,810.1709665526141,810.191400574382,810.2118343963884,810.2322684186292,810.2527022409777,810.2731361636834,810.2935701866227,810.3140040096769,810.3344379330738,810.3548719565952,810.3753058803413,810.395739804444,810.4161737286631,810.4366076531078,810.4570415777926,810.4774755027101,810.4979094278533,810.5183434532373,810.5387772787362,810.5592112045779,810.579645 ...

# %% [markdown]
# Step 3: Running Average or Median

# %%
npts = int(len(f_normalized))
print np.sqrt(npts)
# Out:
# 67.3127031102

# %%
n = 63 #odd number around value of sqrt above
c = copy.copy(f_no_outlier)

for i in range(0,len(f_normalized)-(n)+1):
    low_r = i
    high_r = low_r + n
    center = i + (n+1)/2
    data = f_no_outlier[low_r:high_r]
    running = np.mean(data,dtype=np.float64) #running average
#     running = np.float64( "%f" % np.median(data))
    c[center] = running

# %%
low_r = (n+1)/2
high_r = len(f_no_outlier)-low_r
f_detrend = (f_no_outlier[low_r:high_r]/ c[low_r:high_r])
t_detrend = t_no_outlier[low_r:high_r]

# %%
#Plot is an object
lc_detrend_265 = figure(
    title= title, 
    x_axis_label= x_label,
    y_axis_label='Flux',
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
lc_detrend_265.circle(t_detrend,f_detrend ,legend='Detrend Flux',color='green')
lc_detrend_265.circle(t_no_outlier,f_normalized,legend='Normalized Flux',fill_alpha = .1,line_alpha=.1)
show(lc_detrend_265)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d84111a1-387d-48e0-a65c-a264a5617f78"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d84111a1-387d-48e0-a65c-a264a5617f78");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d84111a1-387d-48e0-a65c-a264a5617f78");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd84111a1-387d-48e0-a65c-a264a5617f78' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {
type":"BoxAnnotation"},{"attributes":{"plot":{"id":"31a2bd97-ff9f-433a-ac9a-0033da26f7e3","subtype":"Figure","type":"Plot"}},"id":"bd11244e-4768-4c67-94c8-5c93213d6019","type":"ResetTool"},{"attributes":{"plot":{"id":"31a2bd97-ff9f-433a-ac9a-0033da26f7e3","subtype":"Figure","type":"Plot"}},"id":"0079fff4-727d-45b6-87a9-12c501ed6886","type":"PanTool"},{"attributes":{"plot":{"id":"31a2bd97-ff9f-433a-ac9a-0033da26f7e3","subtype":"Figure","type":"Plot"}},"id":"f537ce43-938f-41c4-8724-9a700ba39d44","type":"CrosshairTool"},{"attributes":{},"id":"62f2e73d-891c-43e1-a7bd-347d0ac9c72b","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[808.5362531446226,808.5566870482362,808.5771209520753,808.5975548561546,80 ...

# %% [markdown]
# Step 4: Periodogram and BLS

# %%
#real period: 3.568065
# min_period = 3
period3 = periodogram(t_detrend,f_detrend,min_period,max_period,nyquist)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a6c51816-4e63-4c8e-91d1-74f749c0b407"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a6c51816-4e63-4c8e-91d1-74f749c0b407");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a6c51816-4e63-4c8e-91d1-74f749c0b407");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a6c51816-4e63-4c8e-91d1-74f749c0b407' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0851d46d-917c-45d0-a0b9-bddbbf04ed8c":{"roots":{"references":[{"attributes":{"data_source":{"id":"51c61802-eae5-42f1-9ae6-4cf16f52fd7f","type":"ColumnDataSource"},"glyph":{"id":"1c40cfa0-1b2d-4df5-bad6-66534ac2b42d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d8401045-0cf0-4fd2-9f48-7ffaf0d51e80","type":"Line"},"selection_glyph":null},"id":"4613f00b-4dbe-4c47-aedd-87225ab18354","type":"GlyphRenderer"},{"attributes":{},"id":"bfd1922d-42d9-4330-a326-fa65f384b3e5","type":"BasicTicker"},{"attributes":{"ticker":null},"id":"0b66796a-4db5-439a-9b39-8137fe3ad0a1","type":"LogTickFormatter"},{"attributes":{"axis_label":"Period","formatter":{"id":"f188c393-d7bd-46ee-b1ba-f2b195e7f1e2","type":"BasicTickFormatter"},"plot":{"id":"a1889c13-ee08-4e26-9bab-c7ddd8ce4e93","subtype":"Figure","type":"Plot"},"ticker":{"id":"bfd1922d-42d9-4330-a326-fa65f384b3e5","type":"BasicTicker"}},"id":"501096e0-c43f-4627-bd34-cf8eeeeaffbd","type":"LinearAxis"},{"attributes":{},"id":"446668b8-151c-4a43-8464-96f9b919331a","type":"LinearScale"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1c40cfa0-1b2d-4df5-bad6-66534ac2b42d","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8846c1f5-3af1-4e6f-a67f-1b2550107a1c","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"a1889c13-ee08-4e26-9bab-c7ddd8ce4e93","subtype":"Figure","type":"Plot"},"ticker":{"id":"bfd1922d-42d9-4330-a326-fa65f384b3e5","type":"BasicTicker"}},"id":"1b29037d-fb63-44b7-8796-981056dc75c3","type":"Grid"},{"attributes":{"axis_label":"Period","formatter":{"id":"0b66796a-4db5-439a-9b39-8137fe3ad0a1","type":"LogTickFormatter"},"plot":{"id":"a1889c13-ee08-4e26-9bab-c7ddd8ce4e93","subtype":"Figure","type":"Plot"},"ticker":{"id":"7b3402c3-328f-4df6-bc86-0a3a07479816","type":"LogTicker"}},"id":"1245357f-9951-4bb7-8062-e5295affb55f","type":"LogAxis"},{"attributes":{"callback":null,"overlay":{"id":"8846c1f5-3af1-4e6f-a67f-1b2550107a1c","type":"BoxAnnotation"},"plot":{"id":"a1889c13-ee08-4e26-9bab-c7ddd8ce4e93","subtype":"Figure","type":"Plot"},"renderers":[{"id":"4613f00b-4dbe-4c47-aedd-87225ab18354","type":"GlyphRenderer"}]},"id":"9c5bb6eb-d423-437c-bf64-2eea04115c86","type":"BoxSelectTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"433d48e2-dae3-4566-a845-979f37920989","type":"HoverTool"},{"id":"254bcc82-1014-41d4-9ddc-7445b9a56a0d","type":"CrosshairTool"},{"id":"5c14a569-d386-40e0-a37f-e4dd78b323fd","type":"PanTool"},{"id":"2a158813-3703-4d8d-87ec-937bde61c942","type":"WheelZoomTool"},{"id":"36f4c9cb-71f8-4eab-b1b9-4420fc6fd94b","type":"BoxZoomTool"},{"id":"5ba312d1-8ee7-48ab-99f7-2b9f397f5ecf","type":"ResetTool"},{"id":"e9f82bbf-7f39-4845-85a6-1a61b6682a22","type":"TapTool"},{"id":"4e337d17-2fd6-466f-b99c-c5bec37363f4","type":"SaveTool"},{"id":"9c5bb6eb-d423-437c-bf64-2eea04115c86","type":"BoxSelectTool"}]},"id":"f09c2f72-5c26-4eb4-be73-1b773d16284d","type":"Toolbar"},{"attributes":{"callback":null,"plot":{"id":"a1889c13-ee08-4e26-9bab-c7ddd8ce4e93","subtype":"Figure","type":"Plot"}},"id":"433d48e2-dae3-4566-a845-979f37920989","type":"HoverTool"},{"attributes":{"plot":{"id":"a1889c13-ee08-4e26-9bab-c7ddd8ce4e93","subtype":"Figure","type":"Plot"}},"id":"4e337d17-2fd6-466f-b99c-c5bec37363f4","type":"SaveTool"},{"attributes":{"plot":{"id":"a1889c13-ee08-4e26-9bab-c7ddd8ce4e93","subtype":"Figure","type":"Plot"}},"id":"5ba312d1-8ee7-48ab-99f7-2b9f397f5ecf","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"d2e73991-5c31-4b69-b748-eead319ba96e","type":"Title"},{"attributes":{},"id":"9b3fe4da-0f69-48a3-8e7a-997df71f ...
# Finding optimal frequency:
#  - Estimated peak width = 0.0654
#  - Using 5 steps per peak; omega_step = 0.0131
#  - User-specified period range:  0.1 to 32
#  - Computing periods at 4791 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# period = 0.891882214503

# %%
# t_bls - time is an N-dimensional array of timestamps for the light curve,
# f_bls - flux is the N-dimensional light curve array,
# qmi is the minimum transit duration to test, and
# qma is the maximum transit duration to test.
# fmin is the minimum frequency to test,
# df is the frequency grid spacing,
# nb is the number of bins to use in the folded light curve,
# nf is the number of frequency bins to test,

t_bls = t_detrend
f_bls = f_detrend
res = bls(t_bls, f_bls, qmi, qma, fmin, df, nf, nb)
print "Best SR: ", res[0], "\nIngress: ", res[1], "\nEgress: ", res[2], "\nq: ", res[3], \
"\nDepth: ", res[4], "\nPeriod: ", res[5], "\nSDE: ", res[6]


print "correct period: ", 3.568065
# Out:
# Best SR:  1.09910200494e-05
# Ingress:  147
# Egress:  159
# q:  0.0640250727558
# Depth:  4.48983987045e-05
# Period:  3.57142857143
# SDE:  8.20644957928
# correct period:  3.568065

# %%
fmax = round(1./min_period,2) #freq = 1/period
print fmax
steps = (fmax - fmin)/nf
freq = np.arange(fmin, fmax,steps)
plt.plot(freq, res[7], 'k.')
plt.title("SDE = {0}".format(res[6]))
plt.xlabel(r"Frequency (d$^{-1}$)")
plt.ylabel(r"$SR$")
# Out:
# 10.0

# %%
t1 = t_bls[0]
#subtracts t0 from all times
u = t_bls - t1
#avg. flux
s = np.mean(f_bls)

#each flux point subtracted from mean of flux
# v = f_bls - s

## adjustment
#Better cause it shows percentage of change
v = f_bls/s

#plotting data
plt.plot(u, v, 'b.')
plt.title("Data Centering")
plt.xlabel(r"$t - t_0$, (days)")
plt.ylabel(r"$x(t) - \mu$, Flux")

# %%
#converting period to freq
f0 = 1.0/(res[5]) #  freq = 1/T
nbin = nb # number of bin
n = len(t_bls)
ibi = np.zeros(nbin)
y = np.zeros(nbin)
phase = np.linspace(0.0, 1.0, nbin) 

#this loop folds the data for each phase
for i in range(n):
    ph = u[i]*f0 #divides by period
    ph = ph - int(ph) # removes integer, ex. 5.2 ->> .2
    
    #creates mean value of flux over time in a bin
    j = int(nbin*ph) # data to a bin 
    ibi[j] = ibi[j] + 1.0 # number of data in a bin
    y[j] = y[j] + v[i] # sum of light in a bin
# phase [0:120] += 1

plt.plot(phase, y/ibi, 'r.')
plt.title("Period: {0} d  bin: {1}".format(res[5], nbin))
plt.xlabel(r"Phase ($\phi$)")
plt.ylabel(r"Mean value of $x(\phi)$ in a bin")

# %%
plt.plot(phase, y/ibi, 'r.')

#bls fit
fite = np.zeros(nbin) + res[8] # H
#uses ingress(res[1]), and engress(res[2]), to model expected results
fite[res[1]:res[2]+1] = res[9] # L

#added to adjust for throughs being cut off
if res[2] > nbin:
    first_trough = (res[2]-res[1]) - (nbin-res[1])
    fite[0:first_trough] = res[9]
    
#added to adjust for new y axis scale
fite = fite/s + 1

plt.plot(phase, fite)
plt.title("Period: {0} d  bin: {1}".format(res[5], nbin))
plt.xlabel(r"Phase ($\phi$)")
plt.ylabel(r"Mean value of $x(\phi)$ in a bin")

# %% [markdown]
# ## Radius of Planet

# %% [markdown]
# # Ignore Everything Below Here

# %%
# import pandas as pd
# data= pd.read_csv("KOI-265.csv")
# t_detrend1 = np.array(data.BJD)
# f_detrend1= np.array(data.Detrend)

# %%
# #Plot is an object
# lc_detrend_265 = figure(
#     title= title, 
#     x_axis_label= x_label,
#     y_axis_label=y_label,
#     tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

# #adding x and y data for plot
# lc_detrend_265.circle(t_detrend1, f_detrend1,legend='Detrend Flux',color='green')
# # lc_detrend_265.circle(t_no_outlier,normal_normalized,legend='Normalized Flux',fill_alpha = .2,line_alpha=.2)
# show(lc_detrend_265)

# %%
# #using pyfits to open a quarter of data as .fits file
# pyfits.open('c:/Users/rscsa/.kplr/data/lightcurves/010874614/kplr010874614-2009131105131_llc.fits')
# print pyfits.hdu.image.PrimaryHDU()
