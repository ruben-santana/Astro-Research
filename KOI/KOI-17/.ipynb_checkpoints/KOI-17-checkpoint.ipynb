# %% [markdown]
# # Importing Module

# %%
#kplr used to import koi data easier
import kplr
client = kplr.API()

#used to open .fits files
import pyfits
# import astropy

#Used for Plotting
#Experimenting with this instead of using matplot.lib
from bokeh.plotting import figure, show, output_file,output_notebook
#Allows for viewing of plots on jupyter notebooks
output_notebook()

#For Maximum Likelihood
from scipy import optimize

#Used for scientific computing
import numpy as np

#For making copies of data
import copy

#Needed to correct median with 'nan' data points
import math

#For Periodogram
from gatspy.periodic import LombScargleFast

#Importing and notebook setup
# %matplotlib inline

#For Plotting
import matplotlib.pyplot as plt
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="53a25fee-7ac7-4a9c-80c1-0fe24783fbb7">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Making useful functions

# %%
#adjusting light curve data to be a horizontal line
# keeps the first point of the data and makes rest of data horizontal with respect to that point

def h_data (x, y):
    #Using point-slope to make a model linear fit of data
    slope_g = (f[-1]-f[0])/(t[-1]-t[0])
    pt_x = x[20]
    pt_y = y[20]
    print 'slope: ',slope_g
    x = np.linspace(min(t),max(t),len(f))

    #Rough linear fit of data
    new_y = slope_g*(x-pt_x)+pt_y
    
    #Making correction to original data to make horizontal
    first_pt = new_y[0]
    correction = new_y-first_pt
    new_data = y - correction
    
    return new_data

# %%
def periodogram(datax, datay, min_, max_, nyquist):
    #finding periodogram
    model = LombScargleFast().fit(datax, datay)
    period, power = model.periodogram_auto(nyquist_factor=nyquist) # Default 50

    #Plotting
    plt.figure
    plt.plot(period,power)
    plt.ylabel('Power')
    plt.xlabel('Period')# days
    plt.xscale('log')
    #used bottom line to zoom in periodogram
#     plt.xlim(min_-1,max_+10)

    # set range and find period
    model.optimizer.period_range=(min_, max_)
    period = model.best_period
    print("period = {0}".format(period))
    return period

# %%
#Making loop to get Median Smooth
 
#jump - The number of data points you are taking the median of (+1)
### ex. jump = 2, 3 points

def median_smooth(datay,jump):
    #n - determines section of data we are looking at
    n = 1
    
    #Data that is being changed and smoothed
    smooth_flux = copy.copy(datay)

    #median smoothing loop
    while n <= len(smooth_flux)-jump-1:    
        #delta of data from one point to another
        #used in for loop to leave troughs unchanged
        max_change = 0
        #Checks the max delta of data points for each jump
        for i in range (n-1,n+jump-1):
            delta = abs( h_flux[i]-h_flux[i+1])
            if delta > max_change:
                max_change = delta

        #Makes range of points equal to median
        if max_change < 40:
            median = np.median(h_flux[n-1:n+jump])

            #This line corrects errors with data labeled at 'nan'
            if math.isnan(median)==False:
                smooth_flux[n-1:n+jump-1] = median

            #Leaves points unchaged when median is 'nan'
#             else:
#                 print 'Median: ', median
#                 print 'Data Numbers Reserved: ', n-1, ' to ', n+jump-1
#                 print 'Original Data: ', h_flux[n-1:n+jump]
#                 print 'Smooth Data: ', smooth_flux[n-1:n+jump]
#                 print 'Max Change: ', max_change
#                 print ''
#                 print ''

        #Leaves troughs unchaged
#         else:
#             print 'Data Numbers Reserved: ', n-1, ' to ', n+jump-1
#             print 'Original Data: ', datay[n-1:n+jump]
#             print 'Smooth Data: ', smooth_flux[n-1:n+jump]
#             print 'Max Change: ', max_change
#             print ''
#             print ''
        n=n+1
    
    return smooth_flux

# %% [markdown]
# # Importing Data

# %%
# Find a KOI.
koi = client.koi(17.01)

#period, period error (postive & negative)
print 'Period w/ errors: ',(koi.koi_period, koi.koi_period_err1, koi.koi_period_err2)

# This KOI has an associated star.
star = koi.star
print "Associated Star Temperature: ",(star.kic_teff)

#Download the lightcurves for this KOI.
lightcurves = koi.get_light_curves()
# for lc in lightcurves:
#     print (lc.filename)
# Out:
# Period w/ errors:  (0.00078, -0.00078, None)
# Associated Star Temperature:  None

# %% [markdown]
# Getting Like Curve Data

# %%
# Loop over the datasets and read in the data.
time, flux, ferr, quality = [], [], [], []
for lc in lightcurves:
    with lc.open() as f:
        # The lightcurve data are in the first FITS HDU.
        hdu_data = f[1].data
        time.append(hdu_data["time"])
        flux.append(hdu_data["sap_flux"])
        ferr.append(hdu_data["sap_flux_err"])
        quality.append(hdu_data["sap_quality"])

# %% [markdown]
# Plotting Data

# %%
#Time (BJD - 2454833)
#Flux (e-/sec) + ____e+4
#Which quarter do you want to look at?
quarter =1
t = time[quarter]
f = flux[quarter]
#Creating new plot with title and axis labels
#Plot is an object
lc_plot_17 = figure(
    title='KOI-17: Quarter %d '% quarter, 
    x_axis_label='Time (BJD - 2454833)',
    y_axis_label='Flux (e-/sec) e+4',
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
legend = 'KOI: Quarter %d' % quarter
lc_plot_17.line(t, f,legend=legend)

#showing results
show(lc_plot_17)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="15949a1d-6bcf-4a3f-a969-befbe996d031"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("15949a1d-6bcf-4a3f-a969-befbe996d031");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("15949a1d-6bcf-4a3f-a969-befbe996d031");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '15949a1d-6bcf-4a3f-a969-befbe996d031' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"72a86017-5228-4e57-90f7-2757fa6b0e18":{"roots":{"references":[{"attributes":{},"id":"af5def01-b706-47ba-a6f2-8fff6970dd0e","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5bfca41f-e603-4775-bbd5-eff4378cc1f4","subtype":"Figure","type":"Plot"}},"id":"7cdf9638-d6a7-4829-8259-1d901a3966f7","type":"CrosshairTool"},{"attributes":{},"id":"c8f40cd5-4681-4c16-a156-0a886adc42ef","type":"BasicTicker"},{"attributes":{},"id":"0537f0d0-660e-452e-9778-952a86e1e722","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5bfca41f-e603-4775-bbd5-eff4378cc1f4","subtype":"Figure","type":"Plot"},"ticker":{"id":"4c8b8cc3-faec-4ff2-ac04-8b56ffc5a965","type":"BasicTicker"}},"id":"9475fe72-9d72-473b-ba8e-c8134b4826de","type":"Grid"},{"attributes":{"data_source":{"id":"b6882529-8996-4a17-af48-c3474ba4167e","type":"ColumnDataSource"},"glyph":{"id":"36ebfe2c-a330-46cb-9116-7a363f38f375","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"50361186-61f5-4107-abcd-d87fba398396","type":"Line"},"selection_glyph":null},"id":"c50f3bb9-5d72-4bf8-83e1-1c8cea5b2a44","type":"GlyphRenderer"},{"attributes":{},"id":"4c8b8cc3-faec-4ff2-ac04-8b56ffc5a965","type":"BasicTicker"},{"attributes":{"plot":{"id":"5bfca41f-e603-4775-bbd5-eff4378cc1f4","subtype":"Figure","type":"Plot"}},"id":"22369b9b-818c-43d9-aaf1-04ae5ba283dc","type":"SaveTool"},{"attributes":{"callback":null,"plot":{"id":"5bfca41f-e603-4775-bbd5-eff4378cc1f4","subtype":"Figure","type":"Plot"}},"id":"30f9ca07-2d1b-49b2-acd7-ee4aab0d6bdb","type":"TapTool"},{"attributes":{"axis_label":"Time (BJD - 2454833)","formatter":{"id":"0537f0d0-660e-452e-9778-952a86e1e722","type":"BasicTickFormatter"},"plot":{"id":"5bfca41f-e603-4775-bbd5-eff4378cc1f4","subtype":"Figure","type":"Plot"},"ticker":{"id":"4c8b8cc3-faec-4ff2-ac04-8b56ffc5a965","type":"BasicTicker"}},"id":"2d7a1f71-2ba7-41bc-8b49-410b0d250030","type":"LinearAxis"},{"attributes":{"callback":null},"id":"ee40fb12-63a3-43f3-9d1b-d9db0e2ca246","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bf813af0-b6c4-4bd2-b13c-23c2cb1c3ca9","type":"BoxAnnotation"},{"attributes":{"items":[{"id":"8c6d4e8d-fba2-448e-b2e2-a60b008d95e9","type":"LegendItem"}],"plot":{"id":"5bfca41f-e603-4775-bbd5-eff4378cc1f4","subtype":"Figure","type":"Plot"}},"id":"5adf48b9-8c6c-44d2-8481-9749ccb80870","type":"Legend"},{"attributes":{},"id":"69f66fb2-955d-4102-a183-1fcd445dce88","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"5bfca41f-e603-4775-bbd5-eff4378cc1f4","subtype":"Figure","type":"Plot"},"ticker":{"id":"c8f40cd5-4681-4c16-a156-0a886adc42ef","type":"BasicTicker"}},"id":"c8d9f95b-8f21-4634-b3a6-21628d75a1b1","type":"Grid"},{"attributes":{"callback":null},"id":"87826ded-3bc4-4374-8b6f-130f0a0a01ca","type":"DataRange1d"},{"attributes":{"axis_label":"Flux (e-/sec) e+4","formatter":{"id":"af5def01-b706-47ba-a6f2-8fff6970dd0e","type":"BasicTickFormatter"},"plot":{"id":"5bfca41f-e603-4775-bbd5-eff4378cc1f4","subtype":"Figure","type":"Plot"},"ticker":{"id":"c8f40cd5-4681-4c16-a156-0a886adc42ef","type":"BasicTicker"}},"id":"97f44b07-2d4f-4fff-a3ef-2979fab5ca24","type":"LinearAxis"},{"attributes":{"callback":null,"overlay":{"id":"06bdc824-2b27-497d-9aa4-159bdb05d1d7","type":"BoxAnnotation"},"plot":{"id":"5bfca41f-e603-4775-bbd5-eff4378cc1f4","subtype":"Figure","type":"Plot"},"renderers":[{"id":"c50f3bb9-5d72-4bf8-83e1-1c8cea5b2a44","type":"GlyphRenderer"}]},"id":"0a7fefb2-9d0d-488a-8b58-3d904ec22070","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"5bfca41f-e603-4775-bbd5-eff4378cc1f4","subtype":"Figure","type":"Plot"}},"id":"c07c0f81-a3b7-498a-8e2d-7b3b3d52b88d","type":"WheelZoomTool"},{"attributes":{"label":{"value ...

# %% [markdown]
# Fixing Data to Make it Horizontal (Optional)

# %%
#Horizontalizing Data
h_flux = h_data(t,f)

#Plot is an object
lc_h_17 = figure(
    title='KOI-17: Horizontal, Quarter %d '% quarter, 
    x_axis_label='Time (BJD - 2454833)',
    y_axis_label='Flux (e-/sec) e+4',
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
lc_h_17.line(t, h_flux,line_width=1,legend='Horizontal KOI-17',color='green')


#showing results
show(lc_h_17)
# Out:
# slope:  -32.3512869707
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="579386f1-2d90-4d47-8672-f39b7081e35b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("579386f1-2d90-4d47-8672-f39b7081e35b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("579386f1-2d90-4d47-8672-f39b7081e35b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '579386f1-2d90-4d47-8672-f39b7081e35b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bfad2de2-7b0b-4c73-85ce-841e9198488a":{"roots":{"references":[{"attributes":{},"id":"bd3b7152-8e36-46a4-baca-5036eecf1924","type":"BasicTickFormatter"},{"attributes":{},"id":"9a17cca8-9f2a-4ba3-9f14-ec9b66feb8c0","type":"BasicTicker"},{"attributes":{"plot":{"id":"4ce9d923-fee7-4d43-aff1-172f4b5ec6f8","subtype":"Figure","type":"Plot"}},"id":"fe2c8b6c-229e-43fd-a17e-51515c860c9b","type":"CrosshairTool"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7db098ab-474e-49dc-b9b3-9b2a7f7354b6","type":"Line"},{"attributes":{"callback":null,"plot":{"id":"4ce9d923-fee7-4d43-aff1-172f4b5ec6f8","subtype":"Figure","type":"Plot"}},"id":"5897dd7b-4534-432e-8e1f-6e9155d1f64d","type":"HoverTool"},{"attributes":{"plot":{"id":"4ce9d923-fee7-4d43-aff1-172f4b5ec6f8","subtype":"Figure","type":"Plot"}},"id":"fd7833ea-5b29-41f2-b965-e93dfa5c5d72","type":"PanTool"},{"attributes":{"data_source":{"id":"1835e911-b151-4065-9713-493bd03146a4","type":"ColumnDataSource"},"glyph":{"id":"7db098ab-474e-49dc-b9b3-9b2a7f7354b6","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3c2f2787-b7d1-4025-962d-429f395e9a4c","type":"Line"},"selection_glyph":null},"id":"21dc0275-b496-4c9d-ae50-980ad730e891","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b8360068-2ded-47aa-b86a-d2ca39d96453","type":"BoxAnnotation"},{"attributes":{},"id":"2745b797-2495-4795-bc5d-fd3e8282f4e6","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[131.51178135778173,131.53221582827246,131.5526501987697,131.5730844693171,131.59351883981435,131.61395331031235,131.63438758080883,131.6548219512988,131.6752564217968,131.69569079228677,131.71612506272504,131.73655943322228,131.7569939036548,131.77742817415128,131.79786254459032,131.81829701508104,131.83873128551932,131.85916565595835,131.8796000263901,131.90003439682914,131.92046876726818,131.94090313769993,131.96133750808076,131.9817718785198,132.00220624889334,132.02264051933162,132.0430749897132,132.06350936008675,132.08394363046682,132.10437800084765,132.12481247122196,132.14524674160202,132.16568111192464,132.18611558229895,132.20654995262157,132.22698422300164,132.24741859332426,132.26785306364036,132.28828733396222,132.30872170427756,132.32915617454273,132.3495904448646,132.3700248151872,132.39045918544434,132.41089355570875,132.4313279259659,132.4517622962303,132.47219676649547,132.49263103675912,132.51306540695805,132.5334996771635,132.5539341474214,132.5743685176276,132.59480278783303,132.61523725804,132.63567162818072,132.65610599838692,132.67654026853415,132.69697473873384,132.71740910888184,132.73784337902907,132.75827784917055,132.77871221926034,132.79914648940758,132.8195808594901,132.84001532958064,132.86044959966966,132.88088396975218,132.90131843984273,132.92175270987354,132.94218707995606,132.96262144998764,132.98305592001998,133.00349019004352,133.0239245600751,133.04435893004847,133.06479330001457,133.08522767004615,133.10566203996132,133.1260964099274,133.1465307799008,133.16696514987416,133.18739951978205,133.20783398969797,133.22826825961238,133.24870262946206,133.26913699937722,133.28957136923418,133.31000573908386,133.33044000894006,133.35087447879778,133.37130884864746,133.3917432184462,133.41217758824496,133.43261195803643,133.45304632783518,133.47348059757496,133.4939150673672,133.51434943710774,133.53478370684752,133.55521817652334,133.57565254626388,133.59608681594545,133.6165211856205,133.6369556553036,133.65739002497867,133.67782429460203,133.69825876422692,133.71869313385105,133.73912740346714,133.75956177309126,133.77999624265067,133.80043051221583,133.82086488178174,133.8412992 ...

# %%
smooth_flux = median_smooth(h_flux,2)
# Out:
# C:\Users\rscsa\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3569: RuntimeWarning: Invalid value encountered in median
#   RuntimeWarning)

# %% [markdown]
# Median Smoothing of Data

# %%
#Plot is an object
lc_smooth_17 = figure(
    title='KOI-17', 
    x_axis_label='Time (BJD - 2454833)',
    y_axis_label='Flux (e-/sec) e+4',
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
lc_smooth_17.line(t, smooth_flux,legend='Median Smooth Data',color='orange')
# lc_smooth_17.line(t, h_flux,legend='H Data',color='red')

show(lc_smooth_17)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8a135a4f-08eb-4399-9098-5b9baa57dddc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8a135a4f-08eb-4399-9098-5b9baa57dddc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8a135a4f-08eb-4399-9098-5b9baa57dddc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8a135a4f-08eb-4399-9098-5b9baa57dddc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a22a46ad-578f-4a2e-b118-c11d385a60ba":{"roots":{"references":[{"attributes":{"callback":null,"overlay":{"id":"b9505251-290b-4304-b2d4-849ae109111a","type":"BoxAnnotation"},"plot":{"id":"7a3a9167-6805-4ffe-8c84-bf5cca7c1577","subtype":"Figure","type":"Plot"},"renderers":[{"id":"39ed1620-40d9-4ba2-a8ee-59bce48993f7","type":"GlyphRenderer"}]},"id":"97d4cb24-a504-43a0-8177-4296b2095071","type":"BoxSelectTool"},{"attributes":{},"id":"4e7b9849-c545-402a-bf20-9e6a0c8c216d","type":"ToolEvents"},{"attributes":{"callback":null,"plot":{"id":"7a3a9167-6805-4ffe-8c84-bf5cca7c1577","subtype":"Figure","type":"Plot"}},"id":"541d3d9a-751b-48e6-9c75-6be1a1e0be5a","type":"HoverTool"},{"attributes":{"plot":{"id":"7a3a9167-6805-4ffe-8c84-bf5cca7c1577","subtype":"Figure","type":"Plot"}},"id":"ec68ffda-9e61-47aa-9448-3701a426824e","type":"ResetTool"},{"attributes":{"callback":null,"plot":{"id":"7a3a9167-6805-4ffe-8c84-bf5cca7c1577","subtype":"Figure","type":"Plot"}},"id":"743ac1fe-bcfc-4289-833c-5822fc69cbdb","type":"TapTool"},{"attributes":{"data_source":{"id":"ea850e64-6aa9-48bf-8070-3c64262b6412","type":"ColumnDataSource"},"glyph":{"id":"25a132c4-e860-471a-b35e-f70f66f52181","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f5186b6e-b4ae-46ea-8751-3c50c0e54628","type":"Line"},"selection_glyph":null},"id":"39ed1620-40d9-4ba2-a8ee-59bce48993f7","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"7a3a9167-6805-4ffe-8c84-bf5cca7c1577","subtype":"Figure","type":"Plot"}},"id":"6427018c-7ebe-44a4-b298-d26d0ce1acc2","type":"PanTool"},{"attributes":{},"id":"215e83e0-a9e6-4d2a-8ba1-e378294e94eb","type":"BasicTicker"},{"attributes":{"plot":{"id":"7a3a9167-6805-4ffe-8c84-bf5cca7c1577","subtype":"Figure","type":"Plot"},"ticker":{"id":"215e83e0-a9e6-4d2a-8ba1-e378294e94eb","type":"BasicTicker"}},"id":"e9c79aae-c22d-4c6e-b07a-02165897ed12","type":"Grid"},{"attributes":{"axis_label":"Time (BJD - 2454833)","formatter":{"id":"4d666cd7-3ff6-4db2-aee6-fde9c7d2ac57","type":"BasicTickFormatter"},"plot":{"id":"7a3a9167-6805-4ffe-8c84-bf5cca7c1577","subtype":"Figure","type":"Plot"},"ticker":{"id":"215e83e0-a9e6-4d2a-8ba1-e378294e94eb","type":"BasicTicker"}},"id":"081a5b1a-ae32-420c-b9b7-b3d082005c1f","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6dafa102-cc4c-4c5d-88d9-10ab5f647bbe","type":"BoxAnnotation"},{"attributes":{},"id":"bf7000ac-ae68-4c97-a28d-44a1edefb95f","type":"BasicTicker"},{"attributes":{"plot":{"id":"7a3a9167-6805-4ffe-8c84-bf5cca7c1577","subtype":"Figure","type":"Plot"}},"id":"2813a5af-9ed4-4dab-8200-1e40c2e56d32","type":"CrosshairTool"},{"attributes":{"callback":null},"id":"e4f031b3-558c-4c38-9925-c17e8b94b569","type":"DataRange1d"},{"attributes":{"below":[{"id":"081a5b1a-ae32-420c-b9b7-b3d082005c1f","type":"LinearAxis"}],"left":[{"id":"654b708c-ddcd-4a99-b96a-ab3a290c7d92","type":"LinearAxis"}],"renderers":[{"id":"081a5b1a-ae32-420c-b9b7-b3d082005c1f","type":"LinearAxis"},{"id":"e9c79aae-c22d-4c6e-b07a-02165897ed12","type":"Grid"},{"id":"654b708c-ddcd-4a99-b96a-ab3a290c7d92","type":"LinearAxis"},{"id":"6e75206f-5f17-490f-8640-6a126412b68f","type":"Grid"},{"id":"6dafa102-cc4c-4c5d-88d9-10ab5f647bbe","type":"BoxAnnotation"},{"id":"b9505251-290b-4304-b2d4-849ae109111a","type":"BoxAnnotation"},{"id":"70517236-9f73-4d3d-8f4c-dfc83f07dce1","type":"Legend"},{"id":"39ed1620-40d9-4ba2-a8ee-59bce48993f7","type":"GlyphRenderer"}],"title":{"id":"c582374d-8abd-4fd2-a750-865876c61426","type":"Title"},"tool_events":{"id":"4e7b9849-c545-402a-bf20-9e6a0c8c216d","type":"ToolEvents"},"toolbar":{"id":"954aa9ac-167e-49b1-8016-ad56f0451bf6","type":"Toolbar"},"x_range":{"id":"e4f031b3-558c-4c38-9925-c17e8b94b569","type ...

# %% [markdown]
# Finding Period

# %%
### Still need to work on Periodogram
period = periodogram(t, f, 1,30,.5)
# Out:
# Finding optimal frequency:
#  - Estimated peak width = 0.188
#  - Using 5 steps per peak; omega_step = 0.0375
#  - User-specified period range:  1 to 30
#  - Computing periods at 163 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# period = 36.4726030379

# %%
### Step 1: Make a cut_off and only look at that data
### Step 2: Find min flux of each trough
### Step 3: Find the avg. time diff between each local min
###Still need to makes this plot into a function and then will place it up above

# cut_off is the max the point can be to pass the filter
# f_change - change in flux from cutoff
cut_off = 69200
min_f = np.array([])
min_t = np.array([])

#Step 1: filters data to just the points below the cut_off
for i in range(0,len(smooth_flux)):
    f_change = smooth_flux[i] - cut_off
    
    #checks if it's lower than cut off
    if f_change < 0:
        min_f = np.append(min_f,[smooth_flux[i]])
        min_t = np.append(min_t,[t[i]])

# print min_f
# print min_t

#local_min - lowest point of troughs place holder
#check - checks to see if new point is lower than previous local_min
local_min = min_f[0]
troughs_f = np.array([])
troughs_t = np.array([])

#Step 2: filters to just show only the lowest point of each trough
for i in range(0,len(min_f)-1):
    t_change = min_t[i+1] - min_t[i]
    check = min_f[i]
    # checks if it's lower than previous local_min
    if check < local_min:
        local_min = check
        ndata = i
    
    #documents lowest point and resets check for next trough
    if t_change > 1 or i > len(min_f)-3:
        troughs_f = np.append(troughs_f, [local_min])
        troughs_t = np.append(troughs_t, [min_t[ndata]])
        local_min = cut_off
        
# print 'The min of each flux trough: ', troughs_f
# print 'The corresponding time for each trough: ' ,troughs_t
            
all_periods = np.array([])

#Step 3: finding average change in time from each trough
for i in range(0,len(troughs_t)-1):
    period = troughs_t[i+1]-troughs_t[i]
    all_periods = np.append(all_periods,period)

avg_period = np.mean(all_periods)
# print 'All periods: ', all_periods
print 'Avg. period: ', avg_period, ' days.'
# Out:
# Avg. period:  3.23543499684  days.

# %% [markdown]
# # Ignore Everything Below Here

# %%
# #using pyfits to open a quarter of data as .fits file
# pyfits.open('c:/Users/rscsa/.kplr/data/lightcurves/010874614/kplr010874614-2009131105131_llc.fits')
# print pyfits.hdu.image.PrimaryHDU()
