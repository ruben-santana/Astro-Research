# %% [markdown]
# # Importing Module

# %%
#kplr used to import koi data easier
import kplr
client = kplr.API()

#used to open .fits files
import pyfits
# import astropy

#Used for Plotting
#Experimenting with this instead of using matplot.lib
from bokeh.plotting import figure, show, output_file,output_notebook
#Allows for viewing of plots on jupyter notebooks
output_notebook()

#For Maximum Likelihood
from scipy import optimize

#Used for scientific computing
import numpy as np

#For making copies of data
import copy

#Needed to correct median with 'nan' data points
import math

#For Periodogram
from gatspy.periodic import LombScargleFast

#Importing and notebook setup
# %matplotlib inline

#For Plotting
import matplotlib.pyplot as plt
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aaaa9563-ea4a-4cd0-8da4-e8e6c6d0a1dd">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Making useful functions

# %%
#adjusting light curve data to be a horizontal line
# keeps the first point of the data and makes rest of data horizontal with respect to that point

def h_data (x, y):
    #Using point-slope to make a model linear fit of data
    slope_g = (f[-1]-f[0])/(t[-1]-t[0])
    pt_x = x[20]
    pt_y = y[20]
    print 'slope: ',slope_g
    x = np.linspace(min(t),max(t),len(f))

    #Rough linear fit of data
    new_y = slope_g*(x-pt_x)+pt_y
    
    #Making correction to original data to make horizontal
    first_pt = new_y[0]
    correction = new_y-first_pt
    new_data = y - correction
    
    return new_data

# %%
def periodogram(datax, datay, min_, max_, nyquist):
    #finding periodogram
    model = LombScargleFast().fit(datax, datay)
    period, power = model.periodogram_auto(nyquist_factor=nyquist) # Default 50

    #Plotting
    plt.figure
    plt.plot(period,power)
    plt.ylabel('Power')
    plt.xlabel('Period')# days
    plt.xscale('log')
    #used bottom line to zoom in periodogram
#     plt.xlim(min_-1,max_+10)

    # set range and find period
    model.optimizer.period_range=(min_, max_)
    period = model.best_period
    print("period = {0}".format(period))
    return period

# %%
#Making loop to get Median Smooth
 
#jump - The number of pixels you are taking the median
### ex. jump = 7, median over 7 points, replaces values inbetween with median
### Before: [1,2,3,4,5,6,7]
### After:  [1,4,4,4,4,4,7]


def median_smooth(datay,jump,peak_min):
    #n - determines section of data we are looking at
    n = 1
    
    #Data that is being changed and smoothed
    smooth_flux = copy.copy(datay)

    #median smoothing loop
    while n <= len(smooth_flux)-jump-1:    
        #delta of data from one point to another
        #used in for loop to leave troughs unchanged
        max_change = 0
        #Checks the max delta of data points for each jump
        for i in range (n-1,n+jump-1):
            delta = abs( h_flux[i]-h_flux[i+1])
            if delta > max_change:
                max_change = delta

        #Makes range of points equal to median
        if max_change < peak_min:
            median = np.median(h_flux[n-1:n+jump])
            
            #This line corrects errors with data labeled at 'nan'
            if math.isnan(median)==False:
                smooth_flux[n:n+jump-2] = median

#             #Leaves points unchaged when median is 'nan'
#             else:
#                 print 'Median: ', median
#                 print 'Data Numbers Reserved: ', n-1, ' to ', n+jump-1
#                 print 'Original Data: ', h_flux[n-1:n+jump]
#                 print 'Smooth Data: ', smooth_flux[n-1:n+jump]
#                 print 'Max Change: ', max_change
#                 print ''
#                 print ''
# 
#         #Leaves troughs unchaged
#         else:
#             print 'Data Numbers Reserved: ', n-1, ' to ', n+jump-1
#             print 'Original Data: ', datay[n-1:n+jump]
#             print 'Smooth Data: ', smooth_flux[n-1:n+jump]
#             print 'Max Change: ', max_change
#             print ''
#             print ''
        n=n+jump
    print 'First 100 Points'
    print 'Before: '
    print ''
    print h_flux[0:99]
    print ''
    print 'After: '
    print ''
    print smooth_flux[0:99]
    return smooth_flux

# %% [markdown]
# # Importing Data

# %%
# Find a KOI.
koi = client.koi(17.01)

#period, period error (postive & negative)
print 'Period w/ errors: ',(koi.koi_period, koi.koi_period_err1, koi.koi_period_err2)

# This KOI has an associated star.
star = koi.star
print "Associated Star Temperature: ",(star.kic_teff)

#Download the lightcurves for this KOI.
lightcurves = koi.get_light_curves()
# for lc in lightcurves:
#     print (lc.filename)
# Out:
# Period w/ errors:  (0.00078, -0.00078, None)
# Associated Star Temperature:  None

# %% [markdown]
# Getting Like Curve Data

# %%
# Loop over the datasets and read in the data.
time, flux, ferr, quality = [], [], [], []
for lc in lightcurves:
    with lc.open() as f:
        # The lightcurve data are in the first FITS HDU.
        hdu_data = f[1].data
        time.append(hdu_data["time"])
        flux.append(hdu_data["sap_flux"])
        ferr.append(hdu_data["sap_flux_err"])
        quality.append(hdu_data["sap_quality"])

# %% [markdown]
# Plotting Data

# %%
#Time (BJD - 2454833)
#Flux (e-/sec) + ____e+4
#Which quarter do you want to look at?
quarter =1
t = time[quarter]
f = flux[quarter]
#Creating new plot with title and axis labels
#Plot is an object
lc_plot_17 = figure(
    title='KOI-17: Quarter %d '% quarter, 
    x_axis_label='Time (BJD - 2454833)',
    y_axis_label='Flux (e-/sec) e+4',
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
legend = 'KOI: Quarter %d' % quarter
lc_plot_17.line(t, f,legend=legend)

#showing results
show(lc_plot_17)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8eb9d7a8-536e-4aef-97ef-71ff65c5086c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8eb9d7a8-536e-4aef-97ef-71ff65c5086c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8eb9d7a8-536e-4aef-97ef-71ff65c5086c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8eb9d7a8-536e-4aef-97ef-71ff65c5086c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"28dab8d7-9575-45ae-b172-a644518ee5e9":{"roots":{"references":[{"attributes":{},"id":"c4ff05b0-8ec6-4360-a1da-6acc54ab55af","type":"BasicTicker"},{"attributes":{"data_source":{"id":"cc2974f1-ab4f-4632-abd1-9556d96b7b8d","type":"ColumnDataSource"},"glyph":{"id":"96467e8b-ee4e-493d-850a-33b5fcb1f56e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"680c00c2-4ae8-41cd-843e-3124ca73abd4","type":"Line"},"selection_glyph":null},"id":"bb1c93dd-991c-43d1-b082-909c1c6cf3b5","type":"GlyphRenderer"},{"attributes":{},"id":"63b0ad6d-ce19-4557-a574-5a730f467eea","type":"LinearScale"},{"attributes":{"axis_label":"Flux (e-/sec) e+4","formatter":{"id":"d5aea8af-79a8-45e0-9905-a2e48d28964d","type":"BasicTickFormatter"},"plot":{"id":"46a80daa-574d-4934-ba0e-834f592fffbb","subtype":"Figure","type":"Plot"},"ticker":{"id":"a383182b-892f-4766-a019-e97818a12a5b","type":"BasicTicker"}},"id":"52335f05-fffd-4612-80a8-0a64094728e3","type":"LinearAxis"},{"attributes":{"callback":null,"plot":{"id":"46a80daa-574d-4934-ba0e-834f592fffbb","subtype":"Figure","type":"Plot"}},"id":"94129eca-85d5-4baa-81e7-414b6f2b31c8","type":"HoverTool"},{"attributes":{},"id":"a383182b-892f-4766-a019-e97818a12a5b","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"96467e8b-ee4e-493d-850a-33b5fcb1f56e","type":"Line"},{"attributes":{"callback":null},"id":"e68d3a46-247f-403a-97cc-31805b2d93c8","type":"DataRange1d"},{"attributes":{"plot":{"id":"46a80daa-574d-4934-ba0e-834f592fffbb","subtype":"Figure","type":"Plot"},"ticker":{"id":"c4ff05b0-8ec6-4360-a1da-6acc54ab55af","type":"BasicTicker"}},"id":"dab8c3d0-0d74-4f85-b0e0-6369f142c1c7","type":"Grid"},{"attributes":{"axis_label":"Time (BJD - 2454833)","formatter":{"id":"65757f61-6bae-45a6-9c60-576e16dbf8bd","type":"BasicTickFormatter"},"plot":{"id":"46a80daa-574d-4934-ba0e-834f592fffbb","subtype":"Figure","type":"Plot"},"ticker":{"id":"c4ff05b0-8ec6-4360-a1da-6acc54ab55af","type":"BasicTicker"}},"id":"8d5800db-d992-40db-9c29-15e5617ce94f","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c522e6af-266d-4e7f-9aab-cc5dc9c735eb","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":"KOI-17: Quarter 1 "},"id":"f75487e1-92f6-48f3-a1ea-09c4f9d0c0af","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"46a80daa-574d-4934-ba0e-834f592fffbb","subtype":"Figure","type":"Plot"},"ticker":{"id":"a383182b-892f-4766-a019-e97818a12a5b","type":"BasicTicker"}},"id":"7b79c535-ea8f-470b-83a9-5bd664b5fc9e","type":"Grid"},{"attributes":{"plot":{"id":"46a80daa-574d-4934-ba0e-834f592fffbb","subtype":"Figure","type":"Plot"}},"id":"7efe9543-7352-4442-aae7-989fa070785b","type":"CrosshairTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"94129eca-85d5-4baa-81e7-414b6f2b31c8","type":"HoverTool"},{"id":"7efe9543-7352-4442-aae7-989fa070785b","type":"CrosshairTool"},{"id":"ec96a4d1-a769-4ba1-ba3c-6e980ef71636","type":"PanTool"},{"id":"187d9ed6-4cb1-4505-aeef-4f6c0f6e5015","type":"WheelZoomTool"},{"id":"61597dbb-7fb6-4576-aacb-1401efe4a58c","type":"BoxZoomTool"},{"id":"4eab5beb-c5cf-479d-9e6b-aa848ad1fe4f","type":"ResetTool"},{"id":"37cd3486-6a6d-4530-9924-7d0915204aeb","type":"TapTool"},{"id":"fff3447d-6a70-4b77-9039-094fad298b8f","type":"SaveTool"},{"id":"bac424de-3ba2-42ca-8656-3012538170dc","type":"BoxSelectTool"}]},"id":"b381dcc0-956d-43c3-9525-56f40865b8c2","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black" ...

# %% [markdown]
# Fixing Data to Make it Horizontal (Optional)

# %%
#Horizontalizing Data
h_flux = h_data(t,f)

#Plot is an object
lc_h_17 = figure(
    title='KOI-17: Horizontal, Quarter %d '% quarter, 
    x_axis_label='Time (BJD - 2454833)',
    y_axis_label='Flux (e-/sec) e+4',
    tools = 'hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select')

#adding x and y data for plot
lc_h_17.line(t, h_flux,line_width=1,legend='Horizontal KOI-17',color='green')


#showing results
show(lc_h_17)
# Out:
# slope:  -32.3512869707
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ff2b90e0-82fa-4b20-b595-3045875c848e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ff2b90e0-82fa-4b20-b595-3045875c848e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ff2b90e0-82fa-4b20-b595-3045875c848e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ff2b90e0-82fa-4b20-b595-3045875c848e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cd7a6ac3-e49b-4cbb-a1e1-adcdf634380b":{"roots":{"references":[{"attributes":{"below":[{"id":"a8ea4595-0957-4e12-8c85-ba2b03e04079","type":"LinearAxis"}],"left":[{"id":"0997bafd-bd33-4cef-8322-250562c6aa27","type":"LinearAxis"}],"renderers":[{"id":"a8ea4595-0957-4e12-8c85-ba2b03e04079","type":"LinearAxis"},{"id":"37c037ec-4436-4412-8df8-2452046d90d0","type":"Grid"},{"id":"0997bafd-bd33-4cef-8322-250562c6aa27","type":"LinearAxis"},{"id":"db7efd1b-7762-4f5b-934a-c9681e0c44ae","type":"Grid"},{"id":"72233500-3d4d-4af8-93df-f85d944966ef","type":"BoxAnnotation"},{"id":"8ae79288-d4a5-4fdc-b733-b6657472b579","type":"BoxAnnotation"},{"id":"a355b545-a6f7-4144-852d-33a505090575","type":"Legend"},{"id":"a901cfe8-2dbb-4732-8d7c-bf0b70d65f13","type":"GlyphRenderer"}],"title":{"id":"c7b55f51-f726-406e-90b2-6ee51ea6efef","type":"Title"},"tool_events":{"id":"82be239f-9953-49cb-9524-ba371b181082","type":"ToolEvents"},"toolbar":{"id":"97956e48-8250-49ef-9527-8cf79a853984","type":"Toolbar"},"x_range":{"id":"395bae6f-5957-42b4-bece-1d818d036032","type":"DataRange1d"},"x_scale":{"id":"ec107b1a-f8f4-4cab-a4d1-9475dbf08e56","type":"LinearScale"},"y_range":{"id":"f665c736-9ba0-462c-9f81-ded431f70a06","type":"DataRange1d"},"y_scale":{"id":"f596dfac-0d8c-479f-8695-38e34d87bea1","type":"LinearScale"}},"id":"43b8beb6-3904-411f-863b-42d10754d418","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"96fd67ad-a7b2-48b2-812e-77878f6fb67b","type":"ColumnDataSource"},"glyph":{"id":"f1d93516-9c3b-4636-81bc-cb1ab9b6601b","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5daa51f3-a7c9-4a96-ae5f-fd2440e32f03","type":"Line"},"selection_glyph":null},"id":"a901cfe8-2dbb-4732-8d7c-bf0b70d65f13","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"
354,132.94218707995606,132.96262144998764,132.98305592001998,133.00349019004352,133.0239245600751,133.04435893004847,133.06479330001457,133.08522767004615,133.10566203996132,133.1260964099274,133.1465307799008,133.16696514987416,133.18739951978205,133.20783398969797,133.22826825961238,133.24870262946206,133.26913699937722,133.28957136923418,133.31000573908386,133.33044000894006,133.35087447879778,133.37130884864746,133.3917432184462,133.41217758824496,133.43261195803643,133.45304632783518,133.47348059757496,133.4939150673672,133.51434943710774,133.53478370684752,133.55521817652334,133.57565254626388,133.59608681594545,133.6165211856205,133.6369556553036,133.65739002497867,133.67782429460203,133.69825876422692,133.71869313385105,133.73912740346714,133.75956177309126,133.77999624265067,133.80043051221583,133.82086488178174,133.84129925134766,133.8617336208481,133.8821679903558,133.90260235986352,133.92303672936396,133.94347109881346,133.96390546826296,133.98433973770443,134.0047742071547,13 ...

# %% [markdown]
# Finding Period

# %%
### Still need to work on Periodogram
period = periodogram(t, f, 1,30,.5)
# Out:
# Finding optimal frequency:
#  - Estimated peak width = 0.188
#  - Using 5 steps per peak; omega_step = 0.0375
#  - User-specified period range:  1 to 30
#  - Computing periods at 163 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# period = 36.4726030379

# %%
### Step 1: Make a cut_off and only look at that data
### Step 2: Find min flux of each trough
### Step 3: Find the avg. time diff between each local min
###Still need to makes this plot into a function and then will place it up above

# cut_off is the max the point can be to pass the filter
# f_change - change in flux from cutoff
cut_off = 69200
min_f = np.array([])
min_t = np.array([])

#Step 1: filters data to just the points below the cut_off
for i in range(0,len(smooth_flux)):
    f_change = smooth_flux[i] - cut_off
    
    #checks if it's lower than cut off
    if f_change < 0:
        min_f = np.append(min_f,[smooth_flux[i]])
        min_t = np.append(min_t,[t[i]])

# print min_f
# print min_t

#local_min - lowest point of troughs place holder
#check - checks to see if new point is lower than previous local_min
local_min = min_f[0]
troughs_f = np.array([])
troughs_t = np.array([])

#Step 2: filters to just show only the lowest point of each trough
for i in range(0,len(min_f)-1):
    t_change = min_t[i+1] - min_t[i]
    check = min_f[i]
    # checks if it's lower than previous local_min
    if check < local_min:
        local_min = check
        ndata = i
    
    #documents lowest point and resets check for next trough
    if t_change > 1 or i > len(min_f)-3:
        troughs_f = np.append(troughs_f, [local_min])
        troughs_t = np.append(troughs_t, [min_t[ndata]])
        local_min = cut_off
        
# print 'The min of each flux trough: ', troughs_f
# print 'The corresponding time for each trough: ' ,troughs_t
            
all_periods = np.array([])

#Step 3: finding average change in time from each trough
for i in range(0,len(troughs_t)-1):
    period = troughs_t[i+1]-troughs_t[i]
    all_periods = np.append(all_periods,period)

avg_period = np.mean(all_periods)
# print 'All periods: ', all_periods
print 'Avg. period: ', avg_period, ' days.'
# Out:
# Avg. period:  3.23543499684  days.

# %% [markdown]
# # Ignore Everything Below Here

# %%
# #using pyfits to open a quarter of data as .fits file
# pyfits.open('c:/Users/rscsa/.kplr/data/lightcurves/010874614/kplr010874614-2009131105131_llc.fits')
# print pyfits.hdu.image.PrimaryHDU()
