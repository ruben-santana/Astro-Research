# %% [markdown]
# ## HD217014 Fitting & MCMC
#
# Using the K2-24 (EPIC-203771098) dataset, we demonstrate how to use the radvel API to:
#
# - perform a max-likelihood fit
# - do an MCMC exploration of the posterior space
# - plot the results

# %% [markdown]
# Perform some preliminary imports:

# %%
# %matplotlib inline

import os

import matplotlib
import numpy as np
import pylab as pl
import pandas as pd
from scipy import optimize

import corner

import radvel
import radvel.plotting

matplotlib.rcParams['font.size'] = 14

# %% [markdown]
# Define a function that we will use to initialize the ``radvel.RVParameters`` and ``radvel.RVModel`` objects

# %%
def initialize_model():
    time_base = 2420
    params = radvel.RVParameters(1,basis='per tc secosw sesinw logk')
    params['per1'] = 4.23078166873     # period of 1st planet
    params['tc1'] = 2072.79438    # time of inferior conjunction of 1st planet
    params['secosw1'] = 0.01
    params['sesinw1'] = 0.01
    params['logk1'] = 1.74   # velocity semi-amplitude for 1st planet 
    
    mod = radvel.RVModel(params, time_base=time_base)
    mod.params['dvdt'] = 0.0         # slope
    mod.params['curv'] = 0.0         # curvature  
    return mod

# %% [markdown]
# Define a simple plotting function to display the data, model, and residuals

# %%
def plot_results(like):
    fig = pl.figure(figsize=(12,4))
    fig = pl.gcf()
    pl.errorbar(
        like.x, like.model(t)+like.residuals(), 
        yerr=like.yerr, fmt='o'
        )
    pl.plot(ti, like.model(ti))
    fig.set_tight_layout(True)
    pl.xlabel('Time')
    pl.ylabel('RV')
    pl.draw()

# %% [markdown]
# Load up the K2-24 data. In this example the RV data and parameter starting guesses are stored in an csv file

# %%
rv = pd.read_csv('C:/users/rscsa/Research/radvel-master/research/HD217014/HD217014.csv')
# print len(rv)
rv = rv[0:-1]
# print rv
t = np.array(rv.time)
vel = np.array(rv.mnvel)
errvel = np.array(rv.errvel)
ti = np.linspace(rv.time.iloc[0]-5,rv.time.iloc[59-2]+5,50000*(len(t)))
print len(ti)
# Out:
# 2900000

# %% [markdown]
# ### Fit the K2-24 RV data assuming:
#
# 1. circular orbits
# 2. fixed period, time of transit
#
# Set initial guesses for the parameters

# %%
mod = initialize_model()
like = radvel.likelihood.RVLikelihood(mod, t, vel, errvel)
like.params['gamma'] = 1.0
like.params['jit'] = 2.6

# %% [markdown]
# Choose which parameters to vary or fix

# %%
like.vary['curv']= False


print like
# Out:
# parameter                     value      vary
# curv                              0      False
# dvdt                              0       True
# gamma                             1       True
# jit                             2.6       True
# logk1                          1.74       True
# per1                        4.23078       True
# secosw1                        0.01       True
# sesinw1                        0.01       True
# tc1                         2072.79       True

# %% [markdown]
# Plot the initial model

# %%
pl.figure()
plot_results(like)
# radvel.plotting.rv_multipanel_plot(post, epoch=2440000)
# Out:
# C:\Users\rscsa\Anaconda2\lib\site-packages\matplotlib\figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# Well that solution doesn't look very good. Now lets try to optimize the parameters set to vary by maximizing the likelihood.
#
# Initialize a ``radvel.Posterior`` object and add some priors

# %%
post = radvel.posterior.Posterior(like)
post.priors += [radvel.prior.Gaussian('tc1',like.params['tc1'],0.01)]
post.priors += [radvel.prior.Gaussian('per1',like.params['per1'],0.01)]

print post
# Out:
# parameter                     value      vary
# curv                              0      False
# dvdt                              0       True
# gamma                             1       True
# jit                             2.6       True
# logk1                          1.74       True
# per1                        4.23078       True
# secosw1                        0.01       True
# sesinw1                        0.01       True
# tc1                         2072.79       True
#
# Priors
# ------
# Gaussian prior on tc1, mu=2072.79438, sigma=0.01
# Gaussian prior on per1, mu=4.23078166873, sigma=0.01

# %% [markdown]
# Maximize the likelihood and print the updated posterior object

# %%
res  = optimize.minimize(
    post.neglogprob_array,     # objective function is negative log likelihood
    post.get_vary_params(),    # initial variable parameters
    method='Powell',           # Nelder-Mead also works
    )

plot_results(like)             # plot best fit model
print post
radvel.plotting.rv_multipanel_plot(post, epoch=2440000)
# Out:
# parameter                     value      vary
# curv                              0      False
# dvdt                    -0.00119422       True
# gamma                        9.7858       True
# jit                         3.07609       True
# logk1                       4.02691       True
# per1                        4.23098       True
# secosw1                   -0.122192       True
# sesinw1                  -0.0119983       True
# tc1                          2072.8       True
#
# Priors
# ------
# Gaussian prior on tc1, mu=2072.79438, sigma=0.01
# Gaussian prior on per1, mu=4.23078166873, sigma=0.01
# C:\Users\rscsa\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# C:\Users\rscsa\Anaconda2\lib\site-packages\radvel\utils.py:188: RuntimeWarning: invalid value encountered in divide
#   bindat = sy / n
# C:\Users\rscsa\Anaconda2\lib\site-packages\radvel\utils.py:189: RuntimeWarning: invalid value encountered in divide
#   binerr = np.sqrt(sy2/n - bindat*bindat) / np.sqrt(n)
# (<matplotlib.figure.Figure at 0xc5647f0>,
#  [<matplotlib.axes._subplots.AxesSubplot at 0xd0e4ef0>,
#   <matplotlib.axes._axes.Axes at 0xdb31a90>,
#   <matplotlib.axes._subplots.AxesSubplot at 0xc434278>])

# %% [markdown]
# That looks much better!
#
# Now lets use Markov-Chain Monte Carlo (MCMC) to estimate the parameter uncertainties.
# In this example we will run 1000 steps for the sake of speed but in practice you should let it run at least 10000 steps and ~50 walkers. If the chains converge before they reach the maximum number of allowed steps it will automatically stop.

# %%
df = radvel.mcmc(post,nwalkers=50,nrun=10000)
# Out:
# 47500/500000 (9.5%) steps complete; Running 7204.61 steps/s; Mean acceptance rate = 43.8%; Min Tz = 13282.6; Max G-R = 1.11
# Discarding burn-in now that the chains are marginally well-mixed
#
# 202500/500000 (40.5%) steps complete; Running 6738.54 steps/s; Mean acceptance rate = 42.3%; Min Tz = 47391.8; Max G-R = 1.03
# Chains are well-mixed after 205000 steps! MCMC completed in 31.0 seconds

# %% [markdown]
# Now lets make a corner plot to display the posterior distributions.

# %%
radvel.plotting.corner_plot(post, df)

# %% [markdown]
# ### Eccentric Fit
#
# Allow ``secosw`` and ``sesinw`` parameters to vary

# %%
like.vary.update(secosw1=True,
                 sesinw1=True,
                )

# %% [markdown]
# Add an ``EccentricityPrior`` to ensure that eccentricity stays below 1.0. In this example we will also add a Gaussian prior on the jitter (``jit``) parameter with a center at 2.0 m/s and a width of 0.1 m/s.

# %%
post = radvel.posterior.Posterior(like)
post.priors += [radvel.prior.EccentricityPrior(1)]
post.priors += [radvel.prior.Gaussian( 'jit', np.log(1), np.log(15))]

# %% [markdown]
# Optimize the parameters by maximizing the likelihood and plot the result

# %%
res  = optimize.minimize(
    post.neglogprob_array, 
    post.get_vary_params(), 
    method='Powell',)

plot_results(like)
print post
radvel.plotting.rv_multipanel_plot(post, epoch=2440000)
# Out:
# parameter                     value      vary
# curv                              0      False
# dvdt                    -0.00117606       True
# gamma                       8.96767       True
# jit                         1.95183       True
# logk1                        4.0209       True
# per1                        4.23081       True
# secosw1                  -0.0805351       True
# sesinw1                   0.0588886       True
# tc1                         2073.35       True
#
# Priors
# ------
# e1 constrained to be < 0.99
# Gaussian prior on jit, mu=0.0, sigma=2.7080502011
# (<matplotlib.figure.Figure at 0x16e834e0>,
#  [<matplotlib.axes._subplots.AxesSubplot at 0x14531240>,
#   <matplotlib.axes._axes.Axes at 0x17188b70>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x17e2f940>])

# %% [markdown]
# Run the MCMC again

# %%
df = radvel.mcmc(post,threads=1,nwalkers=50,nrun=10000)
# Out:
# 35000/500000 (7.0%) steps complete; Running 5910.16 steps/s; Mean acceptance rate = 44.6%; Min Tz = 13550.5; Max G-R = 1.10
# Discarding burn-in now that the chains are marginally well-mixed
#
# 192500/500000 (38.5%) steps complete; Running 6578.95 steps/s; Mean acceptance rate = 42.9%; Min Tz = 45863.8; Max G-R = 1.03
# Chains are well-mixed after 195000 steps! MCMC completed in 29.8 seconds

# %% [markdown]
# Convert into more physical parameters and make another corner plot

# %%
df['k1'] = np.exp(df['logk1'])
df['jit'] = np.exp(df['jit'])
df['e1'] = df['secosw1']**2 + df['sesinw1']**2


df['ecosw1'] = df['secosw1']*np.sqrt(df['e1'])
df['esinw1'] = df['sesinw1']*np.sqrt(df['e1'])


labels = 'k1 jit e1'.split()
fig = corner.corner(
    df[labels],
    labels=labels,
    levels=[0.68,0.95],
    plot_datapoints=False,
    smooth=True,
    bins=20,
    quantiles=[.14,.5,.84]
    )

# %% [markdown]
# Plot the final solution

# %%
print post
radvel.plotting.rv_multipanel_plot(post, epoch=2440000)
# Out:
# parameter                     value      vary
# curv                              0      False
# dvdt                    -0.00125504       True
# gamma                       9.61621       True
# jit                         1.75747       True
# logk1                       3.99183       True
# per1                        4.23082       True
# secosw1                   0.0460871       True
# sesinw1                   -0.156947       True
# tc1                         2073.28       True
#
# Priors
# ------
# e1 constrained to be < 0.99
# Gaussian prior on jit, mu=0.0, sigma=2.7080502011
# (<matplotlib.figure.Figure at 0x134aa7b8>,
#  [<matplotlib.axes._subplots.AxesSubplot at 0x1733e400>,
#   <matplotlib.axes._axes.Axes at 0x1beebc50>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x1c051898>])

# %%
print like.residuals()
# Out:
# [ 0.2041127   2.60201726  2.99968086  2.17280402  1.44744123 -2.52864514
#  -1.90884624 -2.38561263 -4.35607544 -1.46782563  3.15016668 -2.95655193
#  -0.95130907 -0.21412865  6.15360414 -5.01919613  3.50673806 -4.38905171
#  -1.33255791  2.66424559 -1.65753111  2.51760598 -3.00543485  4.97532016
#   3.78957675  3.11958631  1.43242576  0.79992727  2.95269042 -3.50248425
#   1.12314072  4.40362331  1.61541384 -0.51829701 -0.25493763  0.01308348
#  -0.60460493  2.5119064   1.41819115 -2.5398936   5.07072173 -0.72001156
#   1.72982106  2.0290881   6.20255393  4.16224765  2.21424085 -8.58670123
#  -1.84298866  0.51128345 -0.1947223   2.52324832  0.57940601  4.90088463
#   2.11038795  0.1517601   0.14602341  3.10322438]
